# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %%
folium.Map?

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
folium.Map(
    location=[23.71323, 90.39957],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
routes.head(3)
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2

# %% [markdown]
# Make a map with the airports on it.

# %%
# since there are a lot of airports, making the map can be slow
# so limit it to US airports
us_airports = airports[airports['country']=='United States']
len(us_airports)
#us_airports
# Out:
# 1435

# %%
folium.Marker?

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in us_airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        popup=folium.Popup(row['name'],parse_html=True)
        marker = folium.Marker([row["latitude"], row["longitude"]], popup=popup)
        marker.add_to(airports_map)
        
# Save it to a file (it's kinda big for the notebook)
airports_map.save('airports.html')

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in us_airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        #popup=folium.Popup(row['name'],parse_html=True)
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     )
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %%
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
routes.head()
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')
lex_routes
list(lex_routes)
#airports
# Out:
# ['airline',
#  'airline_id',
#  'source_x',
#  'source_id',
#  'dest',
#  'dest_id',
#  'codeshare',
#  'stops',
#  'equipment',
#  'id',
#  'name',
#  'city',
#  'country',
#  'iata',
#  'icao',
#  'latitude',
#  'longitude',
#  'altitude',
#  'timezone',
#  'dst',
#  'tz',
#  'type',
#  'source_y']

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])

# %%
# here is what our data looks like
lex_routes.head()
#lex_routes.to_csv("lex_routes",encoding='utf-8')
#riter=pd.ExcelWriter('lex_routes.xlsx')
#ex_routes.to_excel(writer,'sheet1')
#riter.save()
list(lex_routes)
# Out:
# ['airline',
#  'airline_id',
#  'source_x',
#  'source_id',
#  'dest',
#  'dest_id',
#  'codeshare',
#  'stops',
#  'equipment',
#  'id_source',
#  'name_source',
#  'city_source',
#  'country_source',
#  'iata_source',
#  'icao_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'timezone_source',
#  'dst_source',
#  'tz_source',
#  'type_source',
#  'source_y',
#  'id_dest',
#  'name_dest',
#  'city_dest',
#  'country_dest',
#  'iata_dest',
#  'icao_dest',
#  'latitude_dest',
#  'longitude_dest',
#  'altitude_dest',
#  'timezone_dest',
#  'dst_dest',
#  'tz_dest',
#  'type_dest',
#  'source']

# %%
pd.DataFrame.drop?

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})
lex_routes.head()
# Out:
#   airline  airline_id source source_id dest dest_id codeshare  stops  \
# 0      9E      3976.0    LEX      4017  ATL    3682       NaN      0
# 1      AA        24.0    LEX      4017  CLT    3876         Y      0
# 2      AA        24.0    LEX      4017  DFW    3670         Y      0
# 3      AA        24.0    LEX      4017  ORD    3830         Y      0
# 4      AF       137.0    LEX      4017  ATL    3682         Y      0
#
#   equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0       CRJ       4017    ...     United States       ATL      KATL
# 1   CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2   ERD ER4       4017    ...     United States       DFW      KDFW
# 3   ERD ER4       4017    ...     United States       ORD      KORD
# 4   CRJ CR9       4017    ...     United States       ATL      KATL
#
#   latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0     33.636700     -84.428101           1026           -5.0         A
# 1     35.214001     -80.943100            748           -5.0         A
# 2     32.896801     -97.038002            607           -6.0         A
# 3     41.978600     -87.904800            672           -6.0         A
# 4     33.636700     -84.428101           1026           -5.0         A
#
#             tz_dest type_dest
# 0  America/New_York   airport
# 1  America/New_York   airport
# 2   America/Chicago   airport
# 3   America/Chicago   airport
# 4  America/New_York   airport
#
# [5 rows x 35 columns]

# %%
list(lex_routes)
# Out:
# ['airline',
#  'airline_id',
#  'source',
#  'source_id',
#  'dest',
#  'dest_id',
#  'codeshare',
#  'stops',
#  'equipment',
#  'id_source',
#  'name_source',
#  'city_source',
#  'country_source',
#  'iata_source',
#  'icao_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'timezone_source',
#  'dst_source',
#  'tz_source',
#  'type_source',
#  'id_dest',
#  'name_dest',
#  'city_dest',
#  'country_dest',
#  'iata_dest',
#  'icao_dest',
#  'latitude_dest',
#  'longitude_dest',
#  'altitude_dest',
#  'timezone_dest',
#  'dst_dest',
#  'tz_dest',
#  'type_dest']

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source source_id dest dest_id codeshare  stops  \
# 0       9E      3976.0    LEX      4017  ATL    3682       NaN      0
# 1       AA        24.0    LEX      4017  CLT    3876         Y      0
# 2       AA        24.0    LEX      4017  DFW    3670         Y      0
# 3       AA        24.0    LEX      4017  ORD    3830         Y      0
# 6       DL      2009.0    LEX      4017  DCA    3520         Y      0
# 7       DL      2009.0    LEX      4017  DTW    3645         Y      0
# 8       DL      2009.0    LEX      4017  LGA    3697       NaN      0
# 9       DL      2009.0    LEX      4017  MSP    3858         Y      0
# 10      G4        35.0    LEX      4017  FLL    3533       NaN      0
# 11      G4        35.0    LEX      4017  PGD    7056       NaN      0
# 12      G4        35.0    LEX      4017  PIE    3617       NaN      0
# 13      G4        35.0    LEX      4017  SFB    4167       NaN      0
# 15      UA      5209.0    LEX      4017  IAH    3550         Y      0
#
#       equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0           CRJ       4017    ...     United States       ATL      KATL
# 1       CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2       ERD ER4       4017    ...     United States       DFW      KDFW
# 3       ERD ER4       4017    ...     United States       ORD      KORD
# 6           CRJ       4017    ...     United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017    ...     United States       DTW      KDTW
# 8           ERJ       4017    ...     United States       LGA      KLGA
# 9           CRJ       4017    ...     United States       MSP      KMSP
# 10          M80       4017    ...     United States       FLL      KFLL
# 11          M80       4017    ...     United States       PGD      KPGD
# 12          320       4017    ...     United States       PIE      KPIE
# 13      M80 320       4017    ...     United States       SFB      KSFB
# 15          ERJ       4017    ...     United States       IAH      KIAH
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 15   America/Chicago   airport
#
# [13 rows x 35 columns]

# %%
for name, row in lex_routes.iterrows():
    print (name,row)
# Out:
# 0 airline                                                           9E
# airline_id                                                      3976
# source                                                           LEX
# source_id                                                       4017
# dest                                                             ATL
# dest_id                                                         3682
# codeshare                                                        NaN
# stops                                                              0
# equipment                                                        CRJ
# id_source                                                       4017
# name_source                                       Blue Grass Airport
# city_source                                             Lexington KY
# country_source                                         United States
# iata_source                                                      LEX
# icao_source                                                     KLEX
# latitude_source                                              38.0365
# longitude_source                                            -84.6059
# altitude_source                                                  979
# timezone_source                                                   -5
# dst_source                                                         A
# tz_source                                           America/New_York
# type_source                                                  airport
# id_dest                                                         3682
# name_dest           Hartsfield Jackson Atlanta International Airport
# city_dest                                                    Atlanta
# country_dest                                           United States
# iata_dest                                                        ATL
# icao_dest                                                       KATL
# latitude_dest                                                33.6367
# longitude_dest                                              -84.4281
# altitude_dest                                                   1026
# timezone_dest                                                     -5
# dst_dest                                                           A
# tz_dest                                             America/New_York
# type_dest                                                    airport
# Name: 0, dtype: object
# 1 airline                                                  AA
# airline_id                                               24
# source                                                  LEX
# source_id                                              4017
# dest                                                    CLT
# dest_id                                                3876
# codeshare                                                 Y
# stops                                                     0
# equipment                                           CR7 CRJ
# id_source                                              4017
# name_source                              Blue Grass Airport
# city_source                                    Lexington KY
# country_source                                United States
# iata_source                                             LEX
# icao_source                                            KLEX
# latitude_source                                     38.0365
# longitude_source                                   -84.6059
# altitude_source                                         979
# timezone_source                                          -5
# dst_source                                                A
# tz_source                                  America/New_York
# type_source                                         airport
# id_dest                                                3876
# name_dest           Charlotte Douglas International Airport
# city_dest                                         Charlotte
# country_dest                                  United States
# iata_dest                                               CLT
# icao_dest                                              KCLT
# latitude_dest                                        35.214
# longitude_dest                                     -80.9431
# altitude_dest                                           748
# timezone_dest                                            -5
# dst_dest                                                  A
# tz_dest                                    America/New_York
# type_dest                                           airport
# Name: 1, dtype: object
# 2 airline                                                  AA
# airline_id                                               24
# source                                                  LEX
# source_id                                              4017
# dest                                                    DFW
# dest_id                                                3670
# codeshare                                                 Y
# stops                                                     0
# equipment                                           ERD ER4
# id_source                                              4017
# name_source                              Blue Grass Airport
# city_source                                    Lexington KY
# country_source                                United States
# iata_source                                             LEX
# icao_source                                            KLEX
# latitude_source                                     38.0365
# longitude_source                                   -84.6059
# altitude_source                                         979
# timezone_source                                          -5
# dst_source                                                A
# tz_source                                  America/New_York
# type_source                                         airport
# id_dest                                                3670
# name_dest           Dallas Fort Worth International Airport
# city_dest                                 Dallas-Fort Worth
# country_dest                                  United States
# iata_dest                                               DFW
# icao_dest                                              KDFW
# latitude_dest                                       32.8968
# longitude_dest                                      -97.038
# altitude_dest                                           607
# timezone_dest                                            -6
# dst_dest                                                  A
# tz_dest                                     America/Chicago
# type_dest                                           airport
# Name: 2, dtype: object
# 3 airline                                               AA
# airline_id                                            24
# source                                               LEX
# source_id                                           4017
# dest                                                 ORD
# dest_id                                             3830
# codeshare                                              Y
# stops                                                  0
# equipment                                        ERD ER4
# id_source                                           4017
# name_source                           Blue Grass Airport
# city_source                                 Lexington KY
# country_source                             United States
# iata_source                                          LEX
# icao_source                                         KLEX
# latitude_source                                  38.0365
# longitude_source                                -84.6059
# altitude_source                                      979
# timezone_source                                       -5
# dst_source                                             A
# tz_source                               America/New_York
# type_source                                      airport
# id_dest                                             3830
# name_dest           Chicago O'Hare International Airport
# city_dest                                        Chicago
# country_dest                               United States
# iata_dest                                            ORD
# icao_dest                                           KORD
# latitude_dest                                    41.9786
# longitude_dest                                  -87.9048
# altitude_dest                                        672
# timezone_dest                                         -6
# dst_dest                                               A
# tz_dest                                  America/Chicago
# type_dest                                        airport
# Name: 3, dtype: object
# 6 airline                                                    DL
# airline_id                                               2009
# source                                                    LEX
# source_id                                                4017
# dest                                                      DCA
# dest_id                                                  3520
# codeshare                                                   Y
# stops                                                       0
# equipment                                                 CRJ
# id_source                                                4017
# name_source                                Blue Grass Airport
# city_source                                      Lexington KY
# country_source                                  United States
# iata_source                                               LEX
# icao_source                                              KLEX
# latitude_source                                       38.0365
# longitude_source                                     -84.6059
# altitude_source                                           979
# timezone_source                                            -5
# dst_source                                                  A
# tz_source                                    America/New_York
# type_source                                           airport
# id_dest                                                  3520
# name_dest           Ronald Reagan Washington National Airport
# city_dest                                          Washington
# country_dest                                    United States
# iata_dest                                                 DCA
# icao_dest                                                KDCA
# latitude_dest                                         38.8521
# longitude_dest                                       -77.0377
# altitude_dest                                              15
# timezone_dest                                              -5
# dst_dest                                                    A
# tz_dest                                      America/New_York
# type_dest                                             airport
# Name: 6, dtype: object
# 7 airline                                                    DL
# airline_id                                               2009
# source                                                    LEX
# source_id                                                4017
# dest                                                      DTW
# dest_id                                                  3645
# codeshare                                                   Y
# stops                                                       0
# equipment                                         CR7 CRJ CR9
# id_source                                                4017
# name_source                                Blue Grass Airport
# city_source                                      Lexington KY
# country_source                                  United States
# iata_source                                               LEX
# icao_source                                              KLEX
# latitude_source                                       38.0365
# longitude_source                                     -84.6059
# altitude_source                                           979
# timezone_source                                            -5
# dst_source                                                  A
# tz_source                                    America/New_York
# type_source                                           airport
# id_dest                                                  3645
# name_dest           Detroit Metropolitan Wayne County Airport
# city_dest                                             Detroit
# country_dest                                    United States
# iata_dest                                                 DTW
# icao_dest                                                KDTW
# latitude_dest                                         42.2124
# longitude_dest                                       -83.3534
# altitude_dest                                             645
# timezone_dest                                              -5
# dst_dest                                                    A
# tz_dest                                      America/New_York
# type_dest                                             airport
# Name: 7, dtype: object
# 8 airline                             DL
# airline_id                        2009
# source                             LEX
# source_id                         4017
# dest                               LGA
# dest_id                           3697
# codeshare                          NaN
# stops                                0
# equipment                          ERJ
# id_source                         4017
# name_source         Blue Grass Airport
# city_source               Lexington KY
# country_source           United States
# iata_source                        LEX
# icao_source                       KLEX
# latitude_source                38.0365
# longitude_source              -84.6059
# altitude_source                    979
# timezone_source                     -5
# dst_source                           A
# tz_source             America/New_York
# type_source                    airport
# id_dest                           3697
# name_dest           La Guardia Airport
# city_dest                     New York
# country_dest             United States
# iata_dest                          LGA
# icao_dest                         KLGA
# latitude_dest                  40.7772
# longitude_dest                -73.8726
# altitude_dest                       21
# timezone_dest                       -5
# dst_dest                             A
# tz_dest               America/New_York
# type_dest                      airport
# Name: 8, dtype: object
# 9 airline                                                            DL
# airline_id                                                       2009
# source                                                            LEX
# source_id                                                        4017
# dest                                                              MSP
# dest_id                                                          3858
# codeshare                                                           Y
# stops                                                               0
# equipment                                                         CRJ
# id_source                                                        4017
# name_source                                        Blue Grass Airport
# city_source                                              Lexington KY
# country_source                                          United States
# iata_source                                                       LEX
# icao_source                                                      KLEX
# latitude_source                                               38.0365
# longitude_source                                             -84.6059
# altitude_source                                                   979
# timezone_source                                                    -5
# dst_source                                                          A
# tz_source                                            America/New_York
# type_source                                                   airport
# id_dest                                                          3858
# name_dest           Minneapolis-St Paul International/Wold-Chamber...
# city_dest                                                 Minneapolis
# country_dest                                            United States
# iata_dest                                                         MSP
# icao_dest                                                        KMSP
# latitude_dest                                                  44.882
# longitude_dest                                               -93.2218
# altitude_dest                                                     841
# timezone_dest                                                      -6
# dst_dest                                                            A
# tz_dest                                               America/Chicago
# type_dest                                                     airport
# Name: 9, dtype: object
# 10 airline                                                          G4
# airline_id                                                       35
# source                                                          LEX
# source_id                                                      4017
# dest                                                            FLL
# dest_id                                                        3533
# codeshare                                                       NaN
# stops                                                             0
# equipment                                                       M80
# id_source                                                      4017
# name_source                                      Blue Grass Airport
# city_source                                            Lexington KY
# country_source                                        United States
# iata_source                                                     LEX
# icao_source                                                    KLEX
# latitude_source                                             38.0365
# longitude_source                                           -84.6059
# altitude_source                                                 979
# timezone_source                                                  -5
# dst_source                                                        A
# tz_source                                          America/New_York
# type_source                                                 airport
# id_dest                                                        3533
# name_dest           Fort Lauderdale Hollywood International Airport
# city_dest                                           Fort Lauderdale
# country_dest                                          United States
# iata_dest                                                       FLL
# icao_dest                                                      KFLL
# latitude_dest                                               26.0726
# longitude_dest                                             -80.1527
# altitude_dest                                                     9
# timezone_dest                                                    -5
# dst_dest                                                          A
# tz_dest                                            America/New_York
# type_dest                                                   airport
# Name: 10, dtype: object
# 11 airline                                   G4
# airline_id                                35
# source                                   LEX
# source_id                               4017
# dest                                     PGD
# dest_id                                 7056
# codeshare                                NaN
# stops                                      0
# equipment                                M80
# id_source                               4017
# name_source               Blue Grass Airport
# city_source                     Lexington KY
# country_source                 United States
# iata_source                              LEX
# icao_source                             KLEX
# latitude_source                      38.0365
# longitude_source                    -84.6059
# altitude_source                          979
# timezone_source                           -5
# dst_source                                 A
# tz_source                   America/New_York
# type_source                          airport
# id_dest                                 7056
# name_dest           Charlotte County Airport
# city_dest                        Punta Gorda
# country_dest                   United States
# iata_dest                                PGD
# icao_dest                               KPGD
# latitude_dest                        26.9202
# longitude_dest                      -81.9905
# altitude_dest                             26
# timezone_dest                             -5
# dst_dest                                   A
# tz_dest                     America/New_York
# type_dest                            airport
# Name: 11, dtype: object
# 12 airline                                                         G4
# airline_id                                                      35
# source                                                         LEX
# source_id                                                     4017
# dest                                                           PIE
# dest_id                                                       3617
# codeshare                                                      NaN
# stops                                                            0
# equipment                                                      320
# id_source                                                     4017
# name_source                                     Blue Grass Airport
# city_source                                           Lexington KY
# country_source                                       United States
# iata_source                                                    LEX
# icao_source                                                   KLEX
# latitude_source                                            38.0365
# longitude_source                                          -84.6059
# altitude_source                                                979
# timezone_source                                                 -5
# dst_source                                                       A
# tz_source                                         America/New_York
# type_source                                                airport
# id_dest                                                       3617
# name_dest           St Petersburg Clearwater International Airport
# city_dest                                           St. Petersburg
# country_dest                                         United States
# iata_dest                                                      PIE
# icao_dest                                                     KPIE
# latitude_dest                                              27.9102
# longitude_dest                                            -82.6874
# altitude_dest                                                   11
# timezone_dest                                                   -5
# dst_dest                                                         A
# tz_dest                                           America/New_York
# type_dest                                                  airport
# Name: 12, dtype: object
# 13 airline                                                G4
# airline_id                                             35
# source                                                LEX
# source_id                                            4017
# dest                                                  SFB
# dest_id                                              4167
# codeshare                                             NaN
# stops                                                   0
# equipment                                         M80 320
# id_source                                            4017
# name_source                            Blue Grass Airport
# city_source                                  Lexington KY
# country_source                              United States
# iata_source                                           LEX
# icao_source                                          KLEX
# latitude_source                                   38.0365
# longitude_source                                 -84.6059
# altitude_source                                       979
# timezone_source                                        -5
# dst_source                                              A
# tz_source                                America/New_York
# type_source                                       airport
# id_dest                                              4167
# name_dest           Orlando Sanford International Airport
# city_dest                                         Sanford
# country_dest                                United States
# iata_dest                                             SFB
# icao_dest                                            KSFB
# latitude_dest                                     28.7776
# longitude_dest                                   -81.2375
# altitude_dest                                          55
# timezone_dest                                          -5
# dst_dest                                                A
# tz_dest                                  America/New_York
# type_dest                                         airport
# Name: 13, dtype: object
# 15 airline                                                       UA
# airline_id                                                  5209
# source                                                       LEX
# source_id                                                   4017
# dest                                                         IAH
# dest_id                                                     3550
# codeshare                                                      Y
# stops                                                          0
# equipment                                                    ERJ
# id_source                                                   4017
# name_source                                   Blue Grass Airport
# city_source                                         Lexington KY
# country_source                                     United States
# iata_source                                                  LEX
# icao_source                                                 KLEX
# latitude_source                                          38.0365
# longitude_source                                        -84.6059
# altitude_source                                              979
# timezone_source                                               -5
# dst_source                                                     A
# tz_source                                       America/New_York
# type_source                                              airport
# id_dest                                                     3550
# name_dest           George Bush Intercontinental Houston Airport
# city_dest                                                Houston
# country_dest                                       United States
# iata_dest                                                    IAH
# icao_dest                                                   KIAH
# latitude_dest                                            29.9844
# longitude_dest                                          -95.3414
# altitude_dest                                                 97
# timezone_dest                                                 -6
# dst_dest                                                       A
# tz_dest                                          America/Chicago
# type_dest                                                airport
# Name: 15, dtype: object

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(4,3),columns = ['col1','col2','col3'])
df
#for row_index,row in df.iterrows():
   #print row_index,row
# Out:
#        col1      col2      col3
# 0  1.842470  1.767846 -0.702400
# 1  0.821517  0.762225 -0.131039
# 2  0.021072 -0.953559  1.301707
# 3  0.619006  1.619487 -0.502059

# %%
for row_index,row in df.iterrows():
   print (row_index,row)
# Out:
# 0 col1    1.842470
# col2    1.767846
# col3   -0.702400
# Name: 0, dtype: float64
# 1 col1    0.821517
# col2    0.762225
# col3   -0.131039
# Name: 1, dtype: float64
# 2 col1    0.021072
# col2   -0.953559
# col3    1.301707
# Name: 2, dtype: float64
# 3 col1    0.619006
# col2    1.619487
# col3   -0.502059
# Name: 3, dtype: float64

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
lex_air.save('lex_air.html')

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p
# Out:
# [(38.034, -84.5),
#  (37.864933929949096, -84.49708149511396),
#  (37.695862920583586, -84.49417629534568),
#  (37.52678697986378, -84.49128425988357),
#  (37.35770611591111, -84.48840524964173),
#  (37.18862033700805, -84.48553912723197),
#  (37.019529651598035, -84.48268575693639),
#  (36.85043406828536, -84.47984500468044),
#  (36.68133359583508, -84.4770167380065),
#  (36.51222824317288, -84.474200826048),
#  (36.343118019385024, -84.47139713950395),
#  (36.17400293371815, -84.46860555061399),
#  (36.00488299557918, -84.46582593313389),
#  (35.83575821453518, -84.46305816231151),
#  (35.66662860031317, -84.46030211486323),
#  (35.49749416279997, -84.45755766895067),
#  (35.328354912042094, -84.45482470415813),
#  (35.15921085824549, -84.45210310147009),
#  (34.99006201177538, -84.44939274324938),
#  (34.82090838315612, -84.44669351321562),
#  (34.65174998307092, -84.44400529642411),
#  (34.48258682236167, -84.44132797924507),
#  (34.3134189120287, -84.43866144934323),
#  (34.14424626323062, -84.43600559565783),
#  (33.975068887284, -84.43336030838299),
#  (33.805886795663184, -84.4307254789483),
#  (33.6367, -84.428101)]

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air.save("lex_air.html")

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.
#
# Bonus: This is the air travel version of the Kevin Bacon game (https://oracleofbacon.org/).  What is the number N, such that you can reach every airport in the world with N or fewer transfers?
#
# Extra Bonus: Use this very important piece of knowledge to impress your friends at parties!

# %%
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airports_cleaned=airports.drop(['name','country','iata','icao','dst','tz','type','source'],axis=1,inplace=True)
#airports_cleaned=airports.drop([' name'],axis=1,inplace=True)
#airports_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-906399a799fe> in <module>()
# ----> 1 airports_cleaned=airports.drop(['name','country','iata','icao','dst','tz','type','source'],axis=1,inplace=True)
#       2 #airports_cleaned=airports.drop([' name'],axis=1,inplace=True)
#       3 #airports_cleaned.head()
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Documents\Anaconda\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['name' 'country' 'iata' 'icao' 'dst' 'tz' 'type' 'source'] not contained in axis

# %%
airports_cleaned=airports.drop(['timezone'],axis=1)
airports_cleaned.head()
# Out:
#    id          city  latitude   longitude  altitude
# 0   1        Goroka -6.081690  145.391998      5282
# 1   2        Madang -5.207080  145.789001        20
# 2   3   Mount Hagen -5.826790  144.296005      5388
# 3   4        Nadzab -6.569803  146.725977       239
# 4   5  Port Moresby -9.443380  147.220001       146

# %%
routes2=routes.drop(['airline'],axis=1)
routes2=routes2.drop(['airline_id'],axis=1)
routes2=routes2.drop(['codeshare'],axis=1)
routes2=routes2.drop(['stops'],axis=1)
routes_cleaned=routes2.drop(['equipment'],axis=1)
routes_cleaned.head()
# Out:
#   source  source_id dest  dest_id
# 0    AER     2965.0  KZN   2990.0
# 1    ASF     2966.0  KZN   2990.0
# 2    ASF     2966.0  MRV   2962.0
# 3    CEK     2968.0  KZN   2990.0
# 4    CEK     2968.0  OVB   4078.0

# %%
lex_origin=routes_cleaned[(routes_cleaned['source']=='LEX')]
#now merge it with airports, by source_id (lex_origin) and id (airports). This will give lat-long for LEX
lex_origin=pd.merge(lex_origin,airports_cleaned,left_on='source_id', right_on='id',how='left')
#lex_origin has source_x, source_y. delete source_y.rename source_x as just source
#lex_origin = lex_origin.drop(['source_y'], axis=1)
#lex_origin = lex_origin.rename(columns={'source_x': 'source'})
lex_origin.head()
# Out:
#   source source_id dest  dest_id    id          city   latitude  longitude  \
# 0    LEX      4017  ATL   3682.0  4017  Lexington KY  38.036499 -84.605904
# 1    LEX      4017  CLT   3876.0  4017  Lexington KY  38.036499 -84.605904
# 2    LEX      4017  DFW   3670.0  4017  Lexington KY  38.036499 -84.605904
# 3    LEX      4017  ORD   3830.0  4017  Lexington KY  38.036499 -84.605904
# 4    LEX      4017  ATL   3682.0  4017  Lexington KY  38.036499 -84.605904
#
#    altitude
# 0       979
# 1       979
# 2       979
# 3       979
# 4       979

# %%
list(lex_origin)
# Out:
# ['source',
#  'source_id',
#  'dest',
#  'dest_id',
#  'id',
#  'city',
#  'latitude',
#  'longitude',
#  'altitude']

# %%
#now merge it with airports again, this time with dest_id and id.
lex_origin=pd.merge(lex_origin,airports_cleaned,
                    left_on='dest_id', right_on='id',
                    how='left',
                    suffixes=['_source','_trns'])

# %%
list(lex_origin)
# Out:
# ['source',
#  'source_id',
#  'dest',
#  'dest_id',
#  'id_source',
#  'city_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'id_trns',
#  'city_trns',
#  'latitude_trns',
#  'longitude_trns',
#  'altitude_trns']

# %%
#rename dest to dest_transfer and dest_id to transfer_id
lex_origin = lex_origin.rename(columns={'dest': 'dest_transfer','dest_id':'transfer_id'})

# %%
list(lex_origin)
# Out:
# ['source',
#  'source_id',
#  'dest_transfer',
#  'transfer_id',
#  'id_source',
#  'city_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'id_trns',
#  'city_trns',
#  'latitude_trns',
#  'longitude_trns',
#  'altitude_trns']

# %%
#now, merge again with routes by transfer_id and id. This will create all the routes from the transfer airport.
lex_transfer_dest=pd.merge(lex_origin,routes_cleaned,
                    left_on='transfer_id', right_on='source_id',how='inner',
                    )#i guess, no need for suffixes, because no column names match

# %%
list(lex_transfer_dest)
#source_x is name, source_x_id is ID. 
#transfer_id is the ID of intermediate airport again equal to id_trns and source_id_y
#so, can drop id_trns and source_id_y
# Out:
# ['source_x',
#  'source_id_x',
#  'dest_transfer',
#  'transfer_id',
#  'id_source',
#  'city_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'id_trns',
#  'city_trns',
#  'latitude_trns',
#  'longitude_trns',
#  'altitude_trns',
#  'source_y',
#  'source_id_y',
#  'dest',
#  'dest_id']

# %%
lex_TD_1=lex_transfer_dest.drop(['source_id_y','id_trns'], axis=1,inplace=True)

# %%
list(lex_transfer_dest)
# Out:
# ['source_x',
#  'source_id_x',
#  'dest_transfer',
#  'transfer_id',
#  'id_source',
#  'city_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'city_trns',
#  'latitude_trns',
#  'longitude_trns',
#  'altitude_trns',
#  'source_y',
#  'dest',
#  'dest_id']

# %%
#merge this with airports to get the lat-long
dataframe_final=pd.merge(lex_transfer_dest,airports_cleaned,
                         left_on='dest_id',right_on='id',
                         how='left')

# %%
list(dataframe_final)
# Out:
# ['source_x',
#  'source_id_x',
#  'dest_transfer',
#  'transfer_id',
#  'id_source',
#  'city_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'city_trns',
#  'latitude_trns',
#  'longitude_trns',
#  'altitude_trns',
#  'source_y',
#  'dest',
#  'dest_id',
#  'id',
#  'city',
#  'latitude',
#  'longitude',
#  'altitude']

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes_final = dataframe_final.drop_duplicates(subset=['source_x', 'dest_transfer','dest'])
lex_routes_final.dropna() #delete all rows that have any NaN value
lex_routes_final
# Out:
#      source_x source_id_x dest_transfer transfer_id  id_source   city_source  \
# 0         LEX        4017           ATL        3682       4017  Lexington KY
# 1         LEX        4017           ATL        3682       4017  Lexington KY
# 2         LEX        4017           ATL        3682       4017  Lexington KY
# 3         LEX        4017           ATL        3682       4017  Lexington KY
# 4         LEX        4017           ATL        3682       4017  Lexington KY
# 5         LEX        4017           ATL        3682       4017  Lexington KY
# 6         LEX        4017           ATL        3682       4017  Lexington KY
# 7         LEX        4017           ATL        3682       4017  Lexington KY
# 8         LEX        4017           ATL        3682       4017  Lexington KY
# 9         LEX        4017           ATL        3682       4017  Lexington KY
# 10        LEX        4017           ATL        3682       4017  Lexington KY
# 11        LEX        4017           ATL        3682       4017  Lexington KY
# 12        LEX        4017           ATL        3682       4017  Lexington KY
# 13        LEX        4017           ATL        3682       4017  Lexington KY
# 14        LEX        4017           ATL        3682       4017  Lexington KY
# 15        LEX        4017           ATL        3682       4017  Lexington KY
# 16        LEX        4017           ATL        3682       4017  Lexington KY
# 17        LEX        4017           ATL        3682       4017  Lexington KY
# 18        LEX        4017           ATL        3682       4017  Lexington KY
# 19        LEX        4017           ATL        3682       4017  Lexington KY
# 20        LEX        4017           ATL        3682       4017  Lexington KY
# 21        LEX        4017           ATL        3682       4017  Lexington KY
# 22        LEX        4017           ATL        3682       4017  Lexington KY
# 23        LEX        4017           ATL        3682       4017  Lexington KY
# 24        LEX        4017           ATL        3682       4017  Lexington KY
# 25        LEX        4017           ATL        3682       4017  Lexington KY
# 26        LEX        4017           ATL        3682       4017  Lexington KY
# 27        LEX        4017           ATL        3682       4017  Lexington KY
# 28        LEX        4017           ATL        3682       4017  Lexington KY
# 29        LEX        4017           ATL        3682       4017  Lexington KY
# ...       ...         ...           ...         ...        ...           ...
# 8138      LEX        4017           IAH        3550       4017  Lexington KY
# 8139      LEX        4017           IAH        3550       4017  Lexington KY
# 8140      LEX        4017           IAH        3550       4017  Lexington KY
# 8141      LEX        4017           IAH        3550       4017  Lexington KY
# 8144      LEX        4017           IAH        3550       4017  Lexington KY
# 8145      LEX        4017           IAH        3550       4017  Lexington KY
# 8146      LEX        4017           IAH        3550       4017  Lexington KY
# 8147      LEX        4017           IAH        3550       4017  Lexington KY
# 8148      LEX        4017           IAH        3550       4017  Lexington KY
# 8150      LEX        4017           IAH        3550       4017  Lexington KY
# 8151      LEX        4017           IAH        3550       4017  Lexington KY
# 8152      LEX        4017           IAH        3550       4017  Lexington KY
# 8153      LEX        4017           IAH        3550       4017  Lexington KY
# 8154      LEX        4017           IAH        3550       4017  Lexington KY
# 8155      LEX        4017           IAH        3550       4017  Lexington KY
# 8156      LEX        4017           IAH        3550       4017  Lexington KY
# 8157      LEX        4017           IAH        3550       4017  Lexington KY
# 8158      LEX        4017           IAH        3550       4017  Lexington KY
# 8159      LEX        4017           IAH        3550       4017  Lexington KY
# 8160      LEX        4017           IAH        3550       4017  Lexington KY
# 8161      LEX        4017           IAH        3550       4017  Lexington KY
# 8162      LEX        4017           IAH        3550       4017  Lexington KY
# 8163      LEX        4017           IAH        3550       4017  Lexington KY
# 8164      LEX        4017           IAH        3550       4017  Lexington KY
# 8165      LEX        4017           IAH        3550       4017  Lexington KY
# 8166      LEX        4017           IAH        3550       4017  Lexington KY
# 8167      LEX        4017           IAH        3550       4017  Lexington KY
# 8170      LEX        4017           IAH        3550       4017  Lexington KY
# 8173      LEX        4017           IAH        3550       4017  Lexington KY
# 8174      LEX        4017           IAH        3550       4017  Lexington KY
#
#       latitude_source  longitude_source  altitude_source city_trns    ...     \
# 0           38.036499        -84.605904              979   Atlanta    ...
# 1           38.036499        -84.605904              979   Atlanta    ...
# 2           38.036499        -84.605904              979   Atlanta    ...
# 3           38.036499        -84.605904              979   Atlanta    ...
# 4           38.036499        -84.605904              979   Atlanta    ...
# 5           38.036499        -84.605904              979   Atlanta    ...
# 6           38.036499        -84.605904              979   Atlanta    ...
# 7           38.036499        -84.605904              979   Atlanta    ...
# 8           38.036499        -84.605904              979   Atlanta    ...
# 9           38.036499        -84.605904              979   Atlanta    ...
# 10          38.036499        -84.605904              979   Atlanta    ...
# 11          38.036499        -84.605904              979   Atlanta    ...
# 12          38.036499        -84.605904              979   Atlanta    ...
# 13          38.036499        -84.605904              979   Atlanta    ...
# 14          38.036499        -84.605904              979   Atlanta    ...
# 15          38.036499        -84.605904              979   Atlanta    ...
# 16          38.036499        -84.605904              979   Atlanta    ...
# 17          38.036499        -84.605904              979   Atlanta    ...
# 18          38.036499        -84.605904              979   Atlanta    ...
# 19          38.036499        -84.605904              979   Atlanta    ...
# 20          38.036499        -84.605904              979   Atlanta    ...
# 21          38.036499        -84.605904              979   Atlanta    ...
# 22          38.036499        -84.605904              979   Atlanta    ...
# 23          38.036499        -84.605904              979   Atlanta    ...
# 24          38.036499        -84.605904              979   Atlanta    ...
# 25          38.036499        -84.605904              979   Atlanta    ...
# 26          38.036499        -84.605904              979   Atlanta    ...
# 27          38.036499        -84.605904              979   Atlanta    ...
# 28          38.036499        -84.605904              979   Atlanta    ...
# 29          38.036499        -84.605904              979   Atlanta    ...
# ...               ...               ...              ...       ...    ...
# 8138        38.036499        -84.605904              979   Houston    ...
# 8139        38.036499        -84.605904              979   Houston    ...
# 8140        38.036499        -84.605904              979   Houston    ...
# 20              Syracuse  43.111198  -76.106300     421.0
# 21             Knoxville  35.811001  -83.994003     981.0
# 22           Bentonville  36.281898  -94.306801    1287.0
# 23             Charlotte  35.214001  -80.943100     748.0
# 24     Dallas-Fort Worth  32.896801  -97.038002     607.0
# 25                London  51.470600   -0.461941      83.0
# 26                 Miami  25.793200  -80.290604       8.0
# 27               Chicago  41.978600  -87.904800     672.0
# 28          Philadelphia  39.871899  -75.241096      36.0
# 29               Phoenix  33.434299 -112.012001    1135.0
# ...                  ...        ...         ...       ...
# 8138      San Pedro Sula  15.452600  -87.923599      91.0
# 8139         San Antonio  29.533701  -98.469803     809.0
# 8140            Savannah  32.127602  -81.202103      50.0
# 8141          Louisville  38.174400  -85.736000     501.0
# 8144          Shreveport  32.446602  -93.825600     258.0
# 8145            San Jose  37.362598 -121.929001      62.0
# 8146   San Jose Del Cabo  23.151800 -109.721001     374.0
# 8147            San Jose   9.993860  -84.208801    3021.0
# 8148            San Juan  18.439400  -66.001801       9.0
# 8150     San Luis Potosi  22.254299 -100.931000    6035.0
# 8151            Saltillo  25.549500 -100.929001    4778.0
# 8152          Sacramento  38.695400 -121.591003      27.0
# 8153           Santa Ana  33.675701 -117.867996      56.0
# 8154           St. Louis  38.748699  -90.370003     618.0
# 8155             Tampico  22.296400  -97.865898      80.0
# 8156         Tegucigalpa  14.060900  -87.217201    3294.0
# 8157               Tampa  27.975500  -82.533203      26.0
# 8158             Torreon  25.568300 -103.411003    3688.0
# 8159               Tulsa  36.198399  -95.888100     677.0
# 8160              Tucson  32.116100 -110.941002    2643.0
# 8161               Tyler  32.354099  -95.402397     544.0
# 8162           Knoxville  35.811001  -83.994003     981.0
# 8163               Quito  -0.129167  -78.357500    7841.0
# 8164           Vera Cruz  19.145901  -96.187302      90.0
# 8165          Valparaiso  30.483200  -86.525398      87.0
# 8166        Villahermosa  17.997000  -92.817398      46.0
# 8167         Bentonville  36.281898  -94.306801    1287.0
# 8170           Vancouver  49.193901 -123.183998      14.0
# 8173         Zihuatanejo  17.601601 -101.460999      26.0
# 8174          Manzanillo  19.144800 -104.558998      30.0
#
# [1541 rows x 21 columns]

# %%
list(lex_routes_final)
# Out:
# ['source_x',
#  'source_id_x',
#  'dest_transfer',
#  'transfer_id',
#  'id_source',
#  'city_source',
#  'latitude_source',
#  'longitude_source',
#  'altitude_source',
#  'city_trns',
#  'latitude_trns',
#  'longitude_trns',
#  'altitude_trns',
#  'source_y',
#  'dest',
#  'dest_id',
#  'id',
#  'city',
#  'latitude',
#  'longitude',
#  'altitude']

# %%
# create a basic map, centered on Lexington
lex_air2 = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)
lex_air2.save('lex_air2.html')

# %%
lex_routes_final2=lex_routes_final[lex_routes_final['longitude'].notnull()]

# %%
lex_routes_final3=lex_routes_final2[lex_routes_final['latitude'].notnull()]
lex_routes_final3
# Out:
# C:\Users\Jawad Mahmud Hoque\Documents\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#
# 8164      LEX        4017           IAH        3550       4017  Lexington KY
# 8165      LEX        4017           IAH        3550       4017  Lexington KY
# 8166      LEX        4017           IAH        3550       4017  Lexington KY
# 8167      LEX        4017           IAH        3550       4017  Lexington KY
# 8170      LEX        4017           IAH        3550       4017  Lexington KY
# 8173      LEX        4017           IAH        3550       4017  Lexington KY
# 8174      LEX        4017           IAH        3550       4017  Lexington KY
#
#       latitude_source  longitude_source  altitude_source city_trns    ...     \
# 0           38.036499        -84.605904              979   Atlanta    ...
# 1           38.036499        -84.605904              979   Atlanta    ...
# 2           38.036499        -84.605904              979   Atlanta    ...
# 3           38.036499        -84.605904              979   Atlanta    ...
# 4           38.036499        -84.605904              979   Atlanta    ...
# 5           38.036499        -84.605904              979   Atlanta    ...
# 6           38.036499        -84.605904              979   Atlanta    ...
# 7           38.036499        -84.605904              979   Atlanta    ...
# 8           38.036499        -84.605904              979   Atlanta    ...
# 9           38.036499        -84.605904              979   Atlanta    ...
# 10          38.036499        -84.605904              979   Atlanta    ...
# 11          38.036499        -84.605904              979   Atlanta    ...
# 12          38.036499        -84.605904              979   Atlanta    ...
# 13          38.036499        -84.605904              979   Atlanta    ...
# 14          38.036499        -84.605904              979   Atlanta    ...
# 15          38.036499        -84.605904              979   Atlanta    ...
# 16          38.036499        -84.605904              979   Atlanta    ...
# 17          38.036499        -84.605904              979   Atlanta    ...
# 18          38.036499        -84.605904              979   Atlanta    ...
# 19          38.036499        -84.605904              979   Atlanta    ...
# 20          38.036499        -84.605904              979   Atlanta    ...
# 21          38.036499        -84.605904              979   Atlanta    ...
# 22          38.036499        -84.605904              979   Atlanta    ...
# 23          38.036499        -84.605904              979   Atlanta    ...
# 24          38.036499        -84.605904              979   Atlanta    ...
# 25          38.036499        -84.605904              979   Atlanta    ...
# 26          38.036499        -84.605904              979   Atlanta    ...
# 27          38.036499        -84.605904              979   Atlanta    ...
# 28          38.036499        -84.605904              979   Atlanta    ...
# 29          38.036499        -84.605904              979   Atlanta    ...
# ...               ...               ...              ...       ...    ...
# 8138        38.036499        -84.605904              979   Houston    ...
# 8139        38.036499        -84.605904              979   Houston    ...
# 8140        38.036499        -84.605904              979   Houston    ...
# 8141        38.036499        -84.605904              979   Houston    ...
# 8144        38.036499        -84.605904              979   Houston    ...
# 8145        38.036499        -84.605904              979   Houston    ...
# 8146        38.036499        -84.605904              979   Houston    ...
# 8147        38.036499        -84.605904              979   Houston    ...
# 8148        38.036499        -84.605904              979   Houston    ...
# 8150        38.036499        -84.605904              979   Houston    ...
# 8151        38.036499        -84.605904              979   Houston    ...
# 8152        38.036499        -84.605904              979   Houston    ...
# 8153        38.036499        -84.605904              979   Houston    ...
# 8154        38.036499        -84.605904              979   Houston    ...
# 8155        38.036499        -84.605904              979   Houston    ...
# 8156        38.036499        -84.605904              979   Houston    ...
# 8157        38.036499        -84.605904              979   Houston    ...
# 8158        38.036499        -84.605904              979   Houston    ...
# 8151      -95.341400             97       IAH  SLW    1810  1810.0
# 8152      -95.341400             97       IAH  SMF    3817  3817.0
# 8153      -95.341400             97       IAH  SNA    3867  3867.0
# 8154      -95.341400             97       IAH  STL    3678  3678.0
# 8155      -95.341400             97       IAH  TAM    1848  1848.0
# 8156      -95.341400             97       IAH  TGU    1776  1776.0
# 8157      -95.341400             97       IAH  TPA    3646  3646.0
# 8158      -95.341400             97       IAH  TRC    1845  1845.0
# 8159      -95.341400             97       IAH  TUL    3855  3855.0
# 8160      -95.341400             97       IAH  TUS    3636  3636.0
# 8161      -95.341400             97       IAH  TYR    3848  3848.0
# 8162      -95.341400             97       IAH  TYS    3676  3676.0
# 8163      -95.341400             97       IAH  UIO    2688  2688.0
# 8164      -95.341400             97       IAH  VER    1854  1854.0
# 8165      -95.341400             97       IAH  VPS    3873  3873.0
# 8166      -95.341400             97       IAH  VSA    1853  1853.0
# 8167      -95.341400             97       IAH  XNA    4356  4356.0
# 8170      -95.341400             97       IAH  YVR     156   156.0
# 8173      -95.341400             97       IAH  ZIH    1856  1856.0
# 8174      -95.341400             97       IAH  ZLO    1858  1858.0
#
#                     city   latitude   longitude  altitude
# 0              Lewisburg  37.858299  -80.399498    2302.0
# 1                  Macon  32.692799  -83.649200     354.0
# 2               Meridian  32.332600  -88.751900     297.0
# 3          Muscle Shoals  34.745300  -87.610199     551.0
# 4     Hattiesburg/Laurel  31.467100  -89.337097     298.0
# 5                 Tupelo  34.268101  -88.769897     346.0
# 6              Kalamazoo  42.234901  -85.552101     874.0
# 7            Chattanooga  35.035301  -85.203796     683.0
# 8           Cedar Rapids  41.884701  -91.710800     869.0
# 9             Charleston  38.373100  -81.593201     981.0
# 10            Cincinnati  39.048801  -84.667801     896.0
# 11            Evansville  38.036999  -87.532402     418.0
# 12            Fort Wayne  40.978500  -85.195099     814.0
# 13            Greensboro  36.097801  -79.937302     925.0
# 14            Greenville  34.895699  -82.218903     964.0
# 15               Lansing  42.778702  -84.587402     861.0
# 16          Lexington KY  38.036499  -84.605904     979.0
# 17               Saginaw  43.532902  -84.079597     668.0
# 18           Minneapolis  44.882000  -93.221802     841.0
# 19            Roanoke VA  37.325500  -79.975403    1175.0
# 20              Syracuse  43.111198  -76.106300     421.0
# 21             Knoxville  35.811001  -83.994003     981.0
# 22           Bentonville  36.281898  -94.306801    1287.0
# 23             Charlotte  35.214001  -80.943100     748.0
# 24     Dallas-Fort Worth  32.896801  -97.038002     607.0
# 25                London  51.470600   -0.461941      83.0
# 26                 Miami  25.793200  -80.290604       8.0
# 27               Chicago  41.978600  -87.904800     672.0
# 28          Philadelphia  39.871899  -75.241096      36.0
# 29               Phoenix  33.434299 -112.012001    1135.0
# ...                  ...        ...         ...       ...
# 8138      San Pedro Sula  15.452600  -87.923599      91.0
# 8139         San Antonio  29.533701  -98.469803     809.0
# 8140            Savannah  32.127602  -81.202103      50.0
# 8141          Louisville  38.174400  -85.736000     501.0
# 8144          Shreveport  32.446602  -93.825600     258.0
# 8145            San Jose  37.362598 -121.929001      62.0
# 8146   San Jose Del Cabo  23.151800 -109.721001     374.0
# 8147            San Jose   9.993860  -84.208801    3021.0
# 8148            San Juan  18.439400  -66.001801       9.0
# 8150     San Luis Potosi  22.254299 -100.931000    6035.0
# 8151            Saltillo  25.549500 -100.929001    4778.0
# 8152          Sacramento  38.695400 -121.591003      27.0
# 8153           Santa Ana  33.675701 -117.867996      56.0
# 8154           St. Louis  38.748699  -90.370003     618.0
# 8155             Tampico  22.296400  -97.865898      80.0
# 8156         Tegucigalpa  14.060900  -87.217201    3294.0
# 8157               Tampa  27.975500  -82.533203      26.0
# 8158             Torreon  25.568300 -103.411003    3688.0
# 8159               Tulsa  36.198399  -95.888100     677.0
# 8160              Tucson  32.116100 -110.941002    2643.0
# 8161               Tyler  32.354099  -95.402397     544.0
# 8162           Knoxville  35.811001  -83.994003     981.0
# 8163               Quito  -0.129167  -78.357500    7841.0
# 8164           Vera Cruz  19.145901  -96.187302      90.0
# 8165          Valparaiso  30.483200  -86.525398      87.0
# 8166        Villahermosa  17.997000  -92.817398      46.0
# 8167         Bentonville  36.281898  -94.306801    1287.0
# 8170           Vancouver  49.193901 -123.183998      14.0
# 8173         Zihuatanejo  17.601601 -101.460999      26.0
# 8174          Manzanillo  19.144800 -104.558998      30.0
#
# [1539 rows x 21 columns]

# %%
# Define some empty sets
airport2_set = set()
route2_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes_final3.iterrows():
    
    if row['source_x'] not in airport2_set: 
        #popup_string = row['city_source'] + ' (' + row['source_x'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5)
        marker.add_to(lex_air2)
        airport2_set.add(row['source_x'])
        
    if row['dest_transfer'] not in airport2_set: 
        #popup_string = row['city_trns'] + '(' + row['dest_transfer'] + ')'
        marker = folium.CircleMarker([row["latitude_trns"], row["longitude_trns"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5)
        marker.add_to(lex_air2)
        airport2_set.add(row['dest_transfer'])
    
    if row['dest'] not in airport2_set: 
        #popup_string = row['city'] + ' (' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     color='red',
                                     fill_color='red', 
                                     radius=5)
        marker.add_to(lex_air2)
        airport2_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source_x'],row['dest_transfer']) not in route2_set:            
        popup_string = row['source_x'] + '-' + row['dest_transfer']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_trns"], row["longitude_trns"])], 
                                weight=2, 
                                )
        line.add_to(lex_air2)
        line2 = folium.PolyLine([(row["latitude_trns"], row["longitude_trns"]), 
                                (row["latitude"], row["longitude"])], 
                                weight=3, 
                                )
        line2.add_to(lex_air2)
        route2_set.add((row['source_x'],row['dest_transfer'],row['dest']))
        
lex_air2
lex_air2.save('lex_air2.html')

# %%
route_set
# Out:
# {('LEX', 'ATL'),
#  ('LEX', 'CLT'),
#  ('LEX', 'DCA'),
#  ('LEX', 'DFW'),
#  ('LEX', 'DTW'),
#  ('LEX', 'FLL'),
#  ('LEX', 'IAH'),
#  ('LEX', 'LGA'),
#  ('LEX', 'MSP'),
#  ('LEX', 'ORD'),
#  ('LEX', 'PGD'),
#  ('LEX', 'PIE'),
#  ('LEX', 'SFB')}
