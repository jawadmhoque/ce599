# %% [markdown]
# # Example: CitiBike data
#
# Adapted from Kelsey Jordahl
# https://gist.github.com/kjordahl/5957573

# %%
import requests  
import json
from pyproj import Proj
from shapely.geometry import Point
import geopandas as gp

# %% [markdown]
# NYC borough boundaries downloaded from [Bytes of the Big Apple](http://www.nyc.gov/html/dcp/download/bytes/nybb_13a.zip)

# %%
boros = gp.GeoDataFrame.from_file('nybb_15b/nybb.shp')

# %% [markdown]
# Load real time bike station data from [CitiBike](http://citibikenyc.com) json API:

# %%
# get the bike data and convert it to a ditcionary
endpoint_url = 'http://citibikenyc.com/stations/json'
response = requests.get(endpoint_url)
data = json.loads(response.text)
data
# Out:
# {'executionTime': '2018-02-21 05:25:15 PM',
#  'stationBeanList': [{'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 36,
#    'city': '',
#    'id': 72,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:40 PM',
#    'latitude': 40.76727216,
#    'location': '',
#    'longitude': -73.99392888,
#    'postalCode': '',
#    'stAddress1': 'W 52 St & 11 Ave',
#    'stAddress2': '',
#    'stationName': 'W 52 St & 11 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 7,
#    'city': '',
#    'id': 79,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:54 PM',
#    'latitude': 40.71911552,
#    'location': '',
#    'longitude': -74.00666661,
#    'postalCode': '',
#    'stAddress1': 'Franklin St & W Broadway',
#    'stAddress2': '',
#    'stationName': 'Franklin St & W Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 12,
#    'city': '',
#    'id': 82,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:54 PM',
#    'latitude': 40.71117416,
#    'location': '',
#    'longitude': -74.00016545,
#    'postalCode': '',
#    'stAddress1': 'St James Pl & Pearl St',
#    'stAddress2': '',
#    'stationName': 'St James Pl & Pearl St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 30,
#    'availableDocks': 30,
#    'city': '',
#    'id': 83,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:37 PM',
#    'latitude': 40.68382604,
#    'location': '',
#    'longitude': -73.97632328,
#    'postalCode': '',
#    'stAddress1': 'Atlantic Ave & Fort Greene Pl',
#    'stAddress2': '',
#    'stationName': 'Atlantic Ave & Fort Greene Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 62},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 11,
#    'city': '',
#    'id': 119,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:17 PM',
#    'latitude': 40.69608941,
#    'location': '',
#    'longitude': -73.97803415,
#    'postalCode': '',
#    'stAddress1': 'Park Ave & St Edwards St',
#    'stAddress2': '',
#    'stationName': 'Park Ave & St Edwards St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 15,
#    'city': '',
#    'id': 120,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:00 PM',
#    'latitude': 40.68676793,
#    'location': '',
#    'longitude': -73.95928168,
#    'postalCode': '',
#    'stAddress1': 'Lexington Ave & Classon Ave',
#    'stAddress2': '',
#    'stationName': 'Lexington Ave & Classon Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 15,
#    'city': '',
#    'id': 127,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:36 PM',
#    'latitude': 40.73172428,
#    'location': '',
#    'longitude': -74.00674436,
#    'postalCode': '',
#    'stAddress1': 'Barrow St & Hudson St',
#    'stAddress2': '',
#    'stationName': 'Barrow St & Hudson St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 16,
#    'availableDocks': 11,
#    'city': '',
#    'id': 128,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:23 PM',
#    'latitude': 40.72710258,
#    'location': '',
#    'longitude': -74.00297088,
#    'postalCode': '',
#    'stAddress1': 'MacDougal St & Prince St',
#    'stAddress2': '',
#    'stationName': 'MacDougal St & Prince St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 11,
#    'city': '',
#    'id': 143,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:23 PM',
#    'latitude': 40.69239502,
#    'location': '',
#    'longitude': -73.99337909,
#    'postalCode': '',
#    'stAddress1': 'Clinton St & Joralemon St',
#    'stAddress2': '',
#    'stationName': 'Clinton St & Joralemon St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 13,
#    'city': '',
#    'id': 144,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:39 PM',
#    'latitude': 40.69839895,
#    'location': '',
#    'longitude': -73.98068914,
#    'postalCode': '',
#    'stAddress1': 'Nassau St & Navy St',
#    'stAddress2': '',
#    'stationName': 'Nassau St & Navy St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 14,
#    'city': '',
#    'id': 146,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:07 PM',
#    'latitude': 40.71625008,
#    'location': '',
#    'longitude': -74.0091059,
#    'postalCode': '',
#    'stAddress1': 'Hudson St & Reade St',
#    'stAddress2': '',
#    'stationName': 'Hudson St & Reade St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 26,
#    'city': '',
#    'id': 150,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:27 PM',
#    'latitude': 40.7208736,
#    'location': '',
#    'longitude': -73.98085795,
#    'postalCode': '',
#    'stAddress1': 'E 2 St & Avenue C',
#    'stAddress2': '',
#    'stationName': 'E 2 St & Avenue C',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 28,
#    'city': '',
#    'id': 151,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:09 PM',
#    'latitude': 40.722103786686034,
#    'location': '',
#    'longitude': -73.99724900722504,
#    'postalCode': '',
#    'stAddress1': 'Cleveland Pl & Spring St',
#    'stAddress2': '',
#    'stationName': 'Cleveland Pl & Spring St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 29,
#    'city': '',
#    'id': 152,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:11 PM',
#    'latitude': 40.71473993,
#    'location': '',
#    'longitude': -74.00910627,
#    'postalCode': '',
#    'stAddress1': 'Warren St & Church St',
#    'stAddress2': '',
#    'stationName': 'Warren St & Church St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 29},
#   {'altitude': '',
#    'availableBikes': 16,
#    'availableDocks': 6,
#    'city': '',
#    'id': 157,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:57 PM',
#    'latitude': 40.69089272,
#    'location': '',
#    'longitude': -73.99612349,
#    'postalCode': '',
#    'stAddress1': 'Henry St & Atlantic Ave',
#    'stAddress2': '',
#    'stationName': 'Henry St & Atlantic Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 18,
#    'availableDocks': 17,
#    'city': '',
#    'id': 161,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:26 PM',
#    'latitude': 40.72917025,
#    'location': '',
#    'longitude': -73.99810231,
#    'postalCode': '',
#    'stAddress1': 'LaGuardia Pl & W 3 St',
#    'stAddress2': '',
#    'stationName': 'LaGuardia Pl & W 3 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 17,
#    'availableDocks': 28,
#    'city': '',
#    'id': 164,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:05 PM',
#    'latitude': 40.75323098,
#    'location': '',
#    'longitude': -73.97032517,
#    'postalCode': '',
#    'stAddress1': 'E 47 St & 2 Ave',
#    'stAddress2': '',
#    'stationName': 'E 47 St & 2 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 47},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 41,
#    'city': '',
#    'id': 167,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:03 PM',
#    'latitude': 40.7489006,
#    'location': '',
#    'longitude': -73.97604882,
#    'postalCode': '',
#    'stAddress1': 'E 39 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 39 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 45},
#   {'altitude': '',
#    'availableBikes': 29,
#    'availableDocks': 18,
#    'city': '',
#    'id': 168,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:15 PM',
#    'latitude': 40.73971301,
#    'location': '',
#    'longitude': -73.99456405,
#    'postalCode': '',
#    'stAddress1': 'W 18 St & 6 Ave',
#    'stAddress2': '',
#    'stationName': 'W 18 St & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 47},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 42,
#    'city': '',
#    'id': 173,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:11 PM',
#    'latitude': 40.76068327096592,
#    'location': '',
#    'longitude': -73.9845272898674,
#    'postalCode': '',
#    'stAddress1': 'Broadway & W 49 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & W 49 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 51},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 27,
#    'city': '',
#    'id': 174,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:59 PM',
#    'latitude': 40.7381765,
#    'location': '',
#    'longitude': -73.97738662,
#    'postalCode': '',
#    'stAddress1': 'E 25 St & 1 Ave',
#    'stAddress2': '',
#    'stationName': 'E 25 St & 1 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 19,
#    'availableDocks': 25,
#    'city': '',
#    'id': 195,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:41 PM',
#    'latitude': 40.70905623,
#    'location': '',
#    'longitude': -74.01043382,
#    'postalCode': '',
#    'stAddress1': 'Liberty St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Liberty St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 45},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 27,
#    'city': '',
#    'id': 212,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:42 PM',
#    'latitude': 40.74334935,
#    'location': '',
#    'longitude': -74.00681753,
#    'postalCode': '',
#    'stAddress1': 'W 16 St & The High Line',
#    'stAddress2': '',
#    'stationName': 'W 16 St & The High Line',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 28},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 21,
#    'city': '',
#    'id': 216,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:03 PM',
#    'latitude': 40.70037867,
#    'location': '',
#    'longitude': -73.99548059,
#    'postalCode': '',
#    'stAddress1': 'Columbia Heights & Cranberry St',
#    'stAddress2': '',
#    'stationName': 'Columbia Heights & Cranberry St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 13,
#    'city': '',
#    'id': 217,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:03 PM',
#    'latitude': 40.70277159,
#    'location': '',
#    'longitude': -73.99383605,
#    'postalCode': '',
#    'stAddress1': 'Old Fulton St',
#    'stAddress2': '',
#    'stationName': 'Old Fulton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 24,
#    'city': '',
#    'id': 223,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:26 PM',
#    'latitude': 40.73781509,
#    'location': '',
#    'longitude': -73.99994661,
#    'postalCode': '',
#    'stAddress1': 'W 13 St & 7 Ave',
#    'stAddress2': '',
#    'stationName': 'W 13 St & 7 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 24,
#    'availableDocks': 31,
#    'city': '',
#    'id': 228,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:41 PM',
#    'latitude': 40.7546011026,
#    'location': '',
#    'longitude': -73.971878855,
#    'postalCode': '',
#    'stAddress1': 'E 48 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 48 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 17,
#    'city': '',
#    'id': 229,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:14 PM',
#    'latitude': 40.72743423,
#    'location': '',
#    'longitude': -73.99379025,
#    'postalCode': '',
#    'stAddress1': 'Great Jones St',
#    'stAddress2': '',
#    'stationName': 'Great Jones St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 15,
#    'city': '',
#    'id': 232,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:45 PM',
#    'latitude': 40.69597683,
#    'location': '',
#    'longitude': -73.99014892,
#    'postalCode': '',
#    'stAddress1': 'Cadman Plaza E & Tillary St',
#    'stAddress2': '',
#    'stationName': 'Cadman Plaza E & Tillary St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 31,
#    'city': '',
#    'id': 236,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:24 PM',
#    'latitude': 40.7284186,
#    'location': '',
#    'longitude': -73.98713956,
#    'postalCode': '',
#    'stAddress1': 'St Marks Pl & 2 Ave',
#    'stAddress2': '',
#    'stationName': 'St Marks Pl & 2 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 37,
#    'city': '',
#    'id': 237,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:18 PM',
#    'latitude': 40.73047309,
#    'location': '',
#    'longitude': -73.98672378,
#    'postalCode': '',
#    'stAddress1': 'E 11 St & 2 Ave',
#    'stAddress2': '',
#    'stationName': 'E 11 St & 2 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 16,
#    'city': '',
#    'id': 238,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:43 PM',
#    'latitude': 40.7361967,
#    'location': '',
#    'longitude': -74.00859207,
#    'postalCode': '',
#    'stAddress1': 'Bank St & Washington St',
#    'stAddress2': '',
#    'stationName': 'Bank St & Washington St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 9,
#    'city': '',
#    'id': 239,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:18 PM',
#    'latitude': 40.69196566,
#    'location': '',
#    'longitude': -73.9813018,
#    'postalCode': '',
#    'stAddress1': 'Willoughby St & Fleet St',
#    'stAddress2': '',
#    'stationName': 'Willoughby St & Fleet St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 14,
#    'city': '',
#    'id': 241,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:08 PM',
#    'latitude': 40.68981035,
#    'location': '',
#    'longitude': -73.97493121,
#    'postalCode': '',
#    'stAddress1': 'DeKalb Ave & S Portland Ave',
#    'stAddress2': '',
#    'stationName': 'DeKalb Ave & S Portland Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 17,
#    'city': '',
#    'id': 242,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:09 PM',
#    'latitude': 40.697787,
#    'location': '',
#    'longitude': -73.973736,
#    'postalCode': '',
#    'stAddress1': 'Carlton Ave & Flushing Ave',
#    'stAddress2': '',
#    'stationName': 'Carlton Ave & Flushing Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 22,
#    'availableDocks': 7,
#    'city': '',
#    'id': 243,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:35 PM',
#    'latitude': 40.688226,
#    'location': '',
#    'longitude': -73.979382,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & Rockwell Pl',
#    'stAddress2': '',
#    'stationName': 'Fulton St & Rockwell Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 21,
#    'city': '',
#    'id': 244,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:13 PM',
#    'latitude': 40.69196035,
#    'location': '',
#    'longitude': -73.96536851,
#    'postalCode': '',
#    'stAddress1': 'Willoughby Ave & Hall St',
#    'stAddress2': '',
#    'stationName': 'Willoughby Ave & Hall St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 21,
#    'city': '',
#    'id': 245,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:48 PM',
#    'latitude': 40.69327018,
#    'location': '',
#    'longitude': -73.97703874,
#    'postalCode': '',
#    'stAddress1': 'Myrtle Ave & St Edwards St',
#    'stAddress2': '',
#    'stationName': 'Myrtle Ave & St Edwards St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 12,
#    'city': '',
#    'id': 247,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:13 PM',
#    'latitude': 40.73535398,
#    'location': '',
#    'longitude': -74.00483091,
#    'postalCode': '',
#    'stAddress1': 'Perry St & Bleecker St',
#    'stAddress2': '',
#    'stationName': 'Perry St & Bleecker St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 20},
#   {'altitude': '',
#    'availableBikes': 15,
#    'availableDocks': 8,
#    'city': '',
#    'id': 248,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:13 PM',
#    'latitude': 40.72185379,
#    'location': '',
#    'longitude': -74.00771779,
#    'postalCode': '',
#    'stAddress1': 'Laight St & Hudson St',
#    'stAddress2': '',
#    'stationName': 'Laight St & Hudson St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 11,
#    'city': '',
#    'id': 249,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:58 PM',
#    'latitude': 40.71870987,
#    'location': '',
#    'longitude': -74.0090009,
#    'postalCode': '',
#    'stAddress1': 'Harrison St & Hudson St',
#    'stAddress2': '',
#    'stationName': 'Harrison St & Hudson St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 4,
#    'city': '',
#    'id': 251,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:16 PM',
#    'latitude': 40.72317958,
#    'location': '',
#    'longitude': -73.99480012,
#    'postalCode': '',
#    'stAddress1': 'Mott St & Prince St',
#    'stAddress2': '',
#    'stationName': 'Mott St & Prince St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 16,
#    'city': '',
#    'id': 252,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:46 PM',
#    'latitude': 40.73226398,
#    'location': '',
#    'longitude': -73.99852205,
#    'postalCode': '',
#    'stAddress1': 'MacDougal St & Washington Sq',
#    'stAddress2': '',
#    'stationName': 'MacDougal St & Washington Sq',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 45,
#    'city': '',
#    'id': 253,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:41 PM',
#    'latitude': 40.73543934,
#    'location': '',
#    'longitude': -73.99453948,
#    'postalCode': '',
#    'stAddress1': 'W 13 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'W 13 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 27,
#    'city': '',
#    'id': 254,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:04 PM',
#    'latitude': 40.73532427,
#    'location': '',
#    'longitude': -73.99800419,
#    'postalCode': '',
#    'stAddress1': 'W 11 St & 6 Ave',
#    'stAddress2': '',
#    'stationName': 'W 11 St & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 13,
#    'city': '',
#    'id': 257,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:40 PM',
#    'latitude': 40.71939226,
#    'location': '',
#    'longitude': -74.00247214,
#    'postalCode': '',
#    'stAddress1': 'Lispenard St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Lispenard St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 22,
#    'city': '',
#    'id': 258,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:09 PM',
#    'latitude': 40.68940747,
#    'location': '',
#    'longitude': -73.96885458,
#    'postalCode': '',
#    'stAddress1': 'DeKalb Ave & Vanderbilt Ave',
#    'stAddress2': '',
#    'stationName': 'DeKalb Ave & Vanderbilt Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 23,
#    'availableDocks': 13,
#    'city': '',
#    'id': 259,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:57 PM',
#    'latitude': 40.70122128,
#    'location': '',
#    'longitude': -74.01234218,
#    'postalCode': '',
#    'stAddress1': 'South St & Whitehall St',
#    'stAddress2': '',
#    'stationName': 'South St & Whitehall St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 8,
#    'city': '',
#    'id': 260,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:10 PM',
#    'latitude': 40.70365182,
#    'location': '',
#    'longitude': -74.01167797,
#    'postalCode': '',
#    'stAddress1': 'Broad St & Bridge St',
#    'stAddress2': '',
#    'stationName': 'Broad St & Bridge St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 13,
#    'city': '',
#    'id': 261,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:37 PM',
#    'latitude': 40.69474881,
#    'location': '',
#    'longitude': -73.98362464,
#    'postalCode': '',
#    'stAddress1': 'Johnson St & Gold St',
#    'stAddress2': '',
#    'stationName': 'Johnson St & Gold St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 22,
#    'city': '',
#    'id': 262,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:53 PM',
#    'latitude': 40.6917823,
#    'location': '',
#    'longitude': -73.9737299,
#    'postalCode': '',
#    'stAddress1': 'Washington Park',
#    'stAddress2': '',
#    'stationName': 'Washington Park',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 6,
#    'city': '',
#    'id': 264,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:00 PM',
#    'latitude': 40.70706456,
#    'location': '',
#    'longitude': -74.00731853,
#    'postalCode': '',
#    'stAddress1': 'Maiden Ln & Pearl St',
#    'stAddress2': '',
#    'stationName': 'Maiden Ln & Pearl St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 32,
#    'city': '',
#    'id': 265,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:28 PM',
#    'latitude': 40.72229346,
#    'location': '',
#    'longitude': -73.99147535,
#    'postalCode': '',
#    'stAddress1': 'Stanton St & Chrystie St',
#    'stAddress2': '',
#    'stationName': 'Stanton St & Chrystie St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 14,
#    'city': '',
#    'id': 266,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:39 PM',
#    'latitude': 40.72368361,
#    'location': '',
#    'longitude': -73.97574813,
#    'postalCode': '',
#    'stAddress1': 'Avenue D & E 8 St',
#    'stAddress2': '',
#    'stationName': 'Avenue D & E 8 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 50,
#    'city': '',
#    'id': 267,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:44 PM',
#    'latitude': 40.75097711,
#    'location': '',
#    'longitude': -73.98765428,
#    'postalCode': '',
#    'stAddress1': 'Broadway & W 36 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & W 36 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 57},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 17,
#    'city': '',
#    'id': 268,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:50 PM',
#    'latitude': 40.71910537,
#    'location': '',
#    'longitude': -73.99973337,
#    'postalCode': '',
#    'stAddress1': 'Howard St & Centre St',
#    'stAddress2': '',
#    'stationName': 'Howard St & Centre St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 21,
#    'city': '',
#    'id': 270,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:42 PM',
#    'latitude': 40.69308257,
#    'location': '',
#    'longitude': -73.97178913,
#    'postalCode': '',
#    'stAddress1': 'Adelphi St & Myrtle Ave',
#    'stAddress2': '',
#    'stationName': 'Adelphi St & Myrtle Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 16,
#    'city': '',
#    'id': 274,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:17 PM',
#    'latitude': 40.68691865,
#    'location': '',
#    'longitude': -73.976682,
#    'postalCode': '',
#    'stAddress1': 'Lafayette Ave & Fort Greene Pl',
#    'stAddress2': '',
#    'stationName': 'Lafayette Ave & Fort Greene Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 13,
#    'city': '',
#    'id': 275,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:31 PM',
#    'latitude': 40.68650065,
#    'location': '',
#    'longitude': -73.96563307,
#    'postalCode': '',
#    'stAddress1': 'Washington Ave & Greene Ave',
#    'stAddress2': '',
#    'stationName': 'Washington Ave & Greene Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 22,
#    'availableDocks': 2,
#    'city': '',
#    'id': 276,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:48 PM',
#    'latitude': 40.71748752,
#    'location': '',
#    'longitude': -74.0104554,
#    'postalCode': '',
#    'stAddress1': 'Duane St & Greenwich St',
#    'stAddress2': '',
#    'stationName': 'Duane St & Greenwich St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 18,
#    'city': '',
#    'id': 278,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:09 PM',
#    'latitude': 40.69766564,
#    'location': '',
#    'longitude': -73.98476437,
#    'postalCode': '',
#    'stAddress1': 'Concord St & Bridge St',
#    'stAddress2': '',
#    'stationName': 'Concord St & Bridge St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 20,
#    'availableDocks': 15,
#    'city': '',
#    'id': 279,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:50 PM',
#    'latitude': 40.707873,
#    'location': '',
#    'longitude': -74.00167,
#    'postalCode': '',
#    'stAddress1': 'Peck Slip & Front St',
#    'stAddress2': '',
#    'stationName': 'Peck Slip & Front St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 36},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 18,
#    'city': '',
#    'id': 280,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:23 PM',
#    'latitude': 40.73331967,
#    'location': '',
#    'longitude': -73.99510132,
#    'postalCode': '',
#    'stAddress1': 'E 10 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'E 10 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 48,
#    'city': '',
#    'id': 281,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:48 PM',
#    'latitude': 40.7643971,
#    'location': '',
#    'longitude': -73.97371465,
#    'postalCode': '',
#    'stAddress1': 'Grand Army Plaza & Central Park S',
#    'stAddress2': '',
#    'stationName': 'Grand Army Plaza & Central Park S',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 57},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 25,
#    'city': '',
#    'id': 282,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:56 PM',
#    'latitude': 40.707644944175705,
#    'location': '',
#    'longitude': -73.96841526031494,
#    'postalCode': '',
#    'stAddress1': 'Kent Ave & S 11 St',
#    'stAddress2': '',
#    'stationName': 'Kent Ave & S 11 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 19,
#    'availableDocks': 24,
#    'city': '',
#    'id': 284,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:03 PM',
#    'latitude': 40.7390169121,
#    'location': '',
#    'longitude': -74.0026376103,
#    'postalCode': '',
#    'stAddress1': 'Greenwich Ave & 8 Ave',
#    'stAddress2': '',
#    'stationName': 'Greenwich Ave & 8 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 43},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 47,
#    'city': '',
#    'id': 285,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:07 PM',
#    'latitude': 40.73454567,
#    'location': '',
#    'longitude': -73.99074142,
#    'postalCode': '',
#    'stAddress1': 'Broadway & E 14 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & E 14 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 51},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 9,
#    'city': '',
#    'id': 289,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:13 PM',
#    'latitude': 40.6845683,
#    'location': '',
#    'longitude': -73.95881081,
#    'postalCode': '',
#    'stAddress1': 'Monroe St & Classon Ave',
#    'stAddress2': '',
#    'stationName': 'Monroe St & Classon Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 15,
#    'city': '',
#    'id': 291,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:19 PM',
#    'latitude': 40.713126,
#    'location': '',
#    'longitude': -73.984844,
#    'postalCode': '',
#    'stAddress1': 'Madison St & Montgomery St',
#    'stAddress2': '',
#    'stationName': 'Madison St & Montgomery St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 20},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 52,
#    'city': '',
#    'id': 293,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:02 PM',
#    'latitude': 40.73020660529954,
#    'location': '',
#    'longitude': -73.99102628231049,
#    'postalCode': '',
#    'stAddress1': 'Lafayette St & E 8 St',
#    'stAddress2': '',
#    'stationName': 'Lafayette St & E 8 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 21,
#    'city': '',
#    'id': 295,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:40 PM',
#    'latitude': 40.71406667,
#    'location': '',
#    'longitude': -73.99293911,
#    'postalCode': '',
#    'stAddress1': 'Pike St & E Broadway',
#    'stAddress2': '',
#    'stationName': 'Pike St & E Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 27,
#    'city': '',
#    'id': 296,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:16 PM',
#    'latitude': 40.71413089,
#    'location': '',
#    'longitude': -73.9970468,
#    'postalCode': '',
#    'stAddress1': 'Division St & Bowery',
#    'stAddress2': '',
#    'stationName': 'Division St & Bowery',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 20,
#    'city': '',
#    'id': 297,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:21 PM',
#    'latitude': 40.734232,
#    'location': '',
#    'longitude': -73.986923,
#    'postalCode': '',
#    'stAddress1': 'E 15 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 15 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 34,
#    'city': '',
#    'id': 301,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:05 PM',
#    'latitude': 40.72217444,
#    'location': '',
#    'longitude': -73.98368779,
#    'postalCode': '',
#    'stAddress1': 'E 2 St & Avenue B',
#    'stAddress2': '',
#    'stationName': 'E 2 St & Avenue B',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 37},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 18,
#    'city': '',
#    'id': 302,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:17 PM',
#    'latitude': 40.72082834,
#    'location': '',
#    'longitude': -73.97793172,
#    'postalCode': '',
#    'stAddress1': 'Avenue D & E 3 St',
#    'stAddress2': '',
#    'stationName': 'Avenue D & E 3 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 22,
#    'availableDocks': 8,
#    'city': '',
#    'id': 303,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:51 PM',
#    'latitude': 40.72362738,
#    'location': '',
#    'longitude': -73.99949601,
#    'postalCode': '',
#    'stAddress1': 'Mercer St & Spring St',
#    'stAddress2': '',
#    'stationName': 'Mercer St & Spring St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 23,
#    'city': '',
#    'id': 304,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:42 PM',
#    'latitude': 40.70463334,
#    'location': '',
#    'longitude': -74.01361706,
#    'postalCode': '',
#    'stAddress1': 'Broadway & Battery Pl',
#    'stAddress2': '',
#    'stationName': 'Broadway & Battery Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 33,
#    'city': '',
#    'id': 305,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:30 PM',
#    'latitude': 40.76095756,
#    'location': '',
#    'longitude': -73.96724467,
#    'postalCode': '',
#    'stAddress1': 'E 58 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 58 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 3,
#    'city': '',
#    'id': 306,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:17 PM',
#    'latitude': 40.70823502,
#    'location': '',
#    'longitude': -74.00530063,
#    'postalCode': '',
#    'stAddress1': 'Cliff St & Fulton St',
#    'stAddress2': '',
#    'stationName': 'Cliff St & Fulton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 17},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 21,
#    'city': '',
#    'id': 307,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:09 PM',
#    'latitude': 40.71427487,
#    'location': '',
#    'longitude': -73.98990025,
#    'postalCode': '',
#    'stAddress1': 'Canal St & Rutgers St',
#    'stAddress2': '',
#    'stationName': 'Canal St & Rutgers St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 0,
#    'city': '',
#    'id': 308,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:49 PM',
#    'latitude': 40.71307916,
#    'location': '',
#    'longitude': -73.99851193,
#    'postalCode': '',
#    'stAddress1': 'St James Pl & Oliver St',
#    'stAddress2': '',
#    'stationName': 'St James Pl & Oliver St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 14,
#    'city': '',
#    'id': 309,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:42 PM',
#    'latitude': 40.7149787,
#    'location': '',
#    'longitude': -74.013012,
#    'postalCode': '',
#    'stAddress1': 'Murray St & West St',
#    'stAddress2': '',
#    'stationName': 'Murray St & West St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 41},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 30,
#    'city': '',
#    'id': 310,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:58 PM',
#    'latitude': 40.68926942,
#    'location': '',
#    'longitude': -73.98912867,
#    'postalCode': '',
#    'stAddress1': 'State St & Smith St',
#    'stAddress2': '',
#    'stationName': 'State St & Smith St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 36},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 24,
#    'city': '',
#    'id': 311,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:20 PM',
#    'latitude': 40.7172274,
#    'location': '',
#    'longitude': -73.98802084,
#    'postalCode': '',
#    'stAddress1': 'Norfolk St & Broome St',
#    'stAddress2': '',
#    'stationName': 'Norfolk St & Broome St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 28,
#    'city': '',
#    'id': 312,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:57 PM',
#    'latitude': 40.722055,
#    'location': '',
#    'longitude': -73.989111,
#    'postalCode': '',
#    'stAddress1': 'Allen St & Stanton St',
#    'stAddress2': '',
#    'stationName': 'Allen St & Stanton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 16,
#    'availableDocks': 7,
#    'city': '',
#    'id': 313,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:59 PM',
#    'latitude': 40.69610226,
#    'location': '',
#    'longitude': -73.96751037,
#    'postalCode': '',
#    'stAddress1': 'Washington Ave & Park Ave',
#    'stAddress2': '',
#    'stationName': 'Washington Ave & Park Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 33,
#    'city': '',
#    'id': 314,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:55 PM',
#    'latitude': 40.69383,
#    'location': '',
#    'longitude': -73.990539,
#    'postalCode': '',
#    'stAddress1': 'Cadman Plaza West & Montague St',
#    'stAddress2': '',
#    'stationName': 'Cadman Plaza West & Montague St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 22,
#    'availableDocks': 4,
#    'city': '',
#    'id': 315,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:57 PM',
#    'latitude': 40.70355377,
#    'location': '',
#    'longitude': -74.00670227,
#    'postalCode': '',
#    'stAddress1': 'South St & Gouverneur Ln',
#    'stAddress2': '',
#    'stationName': 'South St & Gouverneur Ln',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 29},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 36,
#    'city': '',
#    'id': 316,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:02 PM',
#    'latitude': 40.70955958,
#    'location': '',
#    'longitude': -74.00653609,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & William St',
#    'stAddress2': '',
#    'stationName': 'Fulton St & William St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 42},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 20,
#    'city': '',
#    'id': 317,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:07 PM',
#    'latitude': 40.72453734,
#    'location': '',
#    'longitude': -73.98185424,
#    'postalCode': '',
#    'stAddress1': 'E 6 St & Avenue B',
#    'stAddress2': '',
#    'stationName': 'E 6 St & Avenue B',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 28,
#    'availableDocks': 4,
#    'city': '',
#    'id': 319,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:27 PM',
#    'latitude': 40.711066,
#    'location': '',
#    'longitude': -74.009447,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Fulton St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 28,
#    'city': '',
#    'id': 320,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:41 PM',
#    'latitude': 40.717571,
#    'location': '',
#    'longitude': -74.005549,
#    'postalCode': '',
#    'stAddress1': 'Leonard St & Church St',
#    'stAddress2': '',
#    'stationName': 'Leonard St & Church St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 16,
#    'availableDocks': 11,
#    'city': '',
#    'id': 321,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:32 PM',
#    'latitude': 40.69991755,
#    'location': '',
#    'longitude': -73.98971773,
#    'postalCode': '',
#    'stAddress1': 'Cadman Plaza E & Red Cross Pl',
#    'stAddress2': '',
#    'stationName': 'Cadman Plaza E & Red Cross Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 22,
#    'city': '',
#    'id': 322,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:27 PM',
#    'latitude': 40.696192,
#    'location': '',
#    'longitude': -73.991218,
#    'postalCode': '',
#    'stAddress1': 'Clinton St & Tillary St',
#    'stAddress2': '',
#    'stationName': 'Clinton St & Tillary St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 23,
#    'availableDocks': 16,
#    'city': '',
#    'id': 323,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:00 PM',
#    'latitude': 40.69236178,
#    'location': '',
#    'longitude': -73.98631746,
#    'postalCode': '',
#    'stAddress1': 'Lawrence St & Willoughby St',
#    'stAddress2': '',
#    'stationName': 'Lawrence St & Willoughby St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 28,
#    'availableDocks': 23,
#    'city': '',
#    'id': 324,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:20 PM',
#    'latitude': 40.689888,
#    'location': '',
#    'longitude': -73.981013,
#    'postalCode': '',
#    'stAddress1': 'DeKalb Ave & Hudson Ave',
#    'stAddress2': '',
#    'stationName': 'DeKalb Ave & Hudson Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 51},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 28,
#    'city': '',
#    'id': 325,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:11 PM',
#    'latitude': 40.73624527,
#    'location': '',
#    'longitude': -73.98473765,
#    'postalCode': '',
#    'stAddress1': 'E 19 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 19 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 20,
#    'city': '',
#    'id': 326,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:03 PM',
#    'latitude': 40.72953837,
#    'location': '',
#    'longitude': -73.98426726,
#    'postalCode': '',
#    'stAddress1': 'E 11 St & 1 Ave',
#    'stAddress2': '',
#    'stationName': 'E 11 St & 1 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 33,
#    'availableDocks': 6,
#    'city': '',
#    'id': 327,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:11 PM',
#    'latitude': 40.7153379,
#    'location': '',
#    'longitude': -74.01658354,
#    'postalCode': '',
#    'stAddress1': 'Vesey Pl & River Terrace',
#    'stAddress2': '',
#    'stationName': 'Vesey Pl & River Terrace',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 15,
#    'city': '',
#    'id': 328,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:04 PM',
#    'latitude': 40.72405549,
#    'location': '',
#    'longitude': -74.00965965,
#    'postalCode': '',
#    'stAddress1': 'Watts St & Greenwich St',
#    'stAddress2': '',
#    'stationName': 'Watts St & Greenwich St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 10,
#    'city': '',
#    'id': 330,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:35 PM',
#    'latitude': 40.71450451,
#    'location': '',
#    'longitude': -74.00562789,
#    'postalCode': '',
#    'stAddress1': 'Reade St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Reade St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 23,
#    'city': '',
#    'id': 331,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:12 PM',
#    'latitude': 40.71173107,
# ...
#    'stAddress2': '',
#    'stationName': '11 St & 43 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 19,
#    'city': '',
#    'id': 3621,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:10 PM',
#    'latitude': 40.7739825,
#    'location': '',
#    'longitude': -73.9309134,
#    'postalCode': '',
#    'stAddress1': '27 Ave & 9 St',
#    'stAddress2': '',
#    'stationName': '27 Ave & 9 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 14,
#    'city': '',
#    'id': 3622,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:13 PM',
#    'latitude': 40.80756,
#    'location': '',
#    'longitude': -73.939182,
#    'postalCode': '',
#    'stAddress1': 'E 128 St & Madison Ave',
#    'stAddress2': '',
#    'stationName': 'E 128 St & Madison Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 39,
#    'city': '',
#    'id': 3623,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:44 PM',
#    'latitude': 40.8109494,
#    'location': '',
#    'longitude': -73.9634,
#    'postalCode': '',
#    'stAddress1': 'W 120 St & Claremont Ave',
#    'stAddress2': '',
#    'stationName': 'W 120 St & Claremont Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 22,
#    'city': '',
#    'id': 3625,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:47 PM',
#    'latitude': 40.7525758,
#    'location': '',
#    'longitude': -73.9364281,
#    'postalCode': '',
#    'stAddress1': '28 St & 40 Ave',
#    'stAddress2': '',
#    'stationName': '28 St & 40 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 22},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 0,
#    'city': '',
#    'id': 3628,
#    'landMark': '',
#    'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#    'latitude': 40.8025566,
#    'location': '',
#    'longitude': -73.9490782,
#    'postalCode': '',
#    'stAddress1': 'Coming Soon: Lenox Ave & W 117 St',
#    'stAddress2': '',
#    'stationName': 'Coming Soon: Lenox Ave & W 117 St',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 0},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 6,
#    'city': '',
#    'id': 3629,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:33 PM',
#    'latitude': 40.809495347779475,
#    'location': '',
#    'longitude': -73.94776493310928,
#    'postalCode': '',
#    'stAddress1': 'Adam Clayton Powell Blvd & W 126 St',
#    'stAddress2': '',
#    'stationName': 'Adam Clayton Powell Blvd & W 126 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 0,
#    'city': '',
#    'id': 3630,
#    'landMark': '',
#    'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#    'latitude': 40.8038654,
#    'location': '',
#    'longitude': -73.9559308,
#    'postalCode': '',
#    'stAddress1': 'Coming Soon: Frederick Douglass Blvd & W 115 St',
#    'stAddress2': '',
#    'stationName': 'Coming Soon: Frederick Douglass Blvd & W 115 St',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 0},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 24,
#    'city': '',
#    'id': 3631,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:17 PM',
#    'latitude': 40.666563,
#    'location': '',
#    'longitude': -73.956741,
#    'postalCode': '',
#    'stAddress1': 'Crown St & Bedford Ave',
#    'stAddress2': '',
#    'stationName': 'Crown St & Bedford Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 23,
#    'city': '',
#    'id': 3632,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:51 PM',
#    'latitude': 40.728048571362606,
#    'location': '',
#    'longitude': -73.97881150245667,
#    'postalCode': '',
#    'stAddress1': 'E 12 St & Avenue B',
#    'stAddress2': '',
#    'stationName': 'E 12 St & Avenue B',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 32,
#    'city': '',
#    'id': 3635,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:11 PM',
#    'latitude': 40.75462324029105,
#    'location': '',
#    'longitude': -73.99516761302948,
#    'postalCode': '',
#    'stAddress1': 'W 36 St & 9 Ave',
#    'stAddress2': '',
#    'stationName': 'W 36 St & 9 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 41},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 29,
#    'city': '',
#    'id': 3637,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:10 PM',
#    'latitude': 40.683238654603414,
#    'location': '',
#    'longitude': -73.96599590778351,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & Waverly Ave',
#    'stAddress2': '',
#    'stationName': 'Fulton St & Waverly Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 17,
#    'availableDocks': 1,
#    'city': '',
#    'id': 3638,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:41 PM',
#    'latitude': 40.7242941,
#    'location': '',
#    'longitude': -74.0354826,
#    'postalCode': '',
#    'stAddress1': 'Washington St',
#    'stAddress2': '',
#    'stationName': 'Washington St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 18},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 27,
#    'city': '',
#    'id': 3639,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:24 PM',
#    'latitude': 40.7192517,
#    'location': '',
#    'longitude': -74.034234,
#    'postalCode': '',
#    'stAddress1': 'Harborside',
#    'stAddress2': '',
#    'stationName': 'Harborside',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 15,
#    'city': '',
#    'id': 3640,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:52 PM',
#    'latitude': 40.73367,
#    'location': '',
#    'longitude': -74.0625,
#    'postalCode': '',
#    'stAddress1': 'Journal Square',
#    'stAddress2': '',
#    'stationName': 'Journal Square',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 18},
#   {'altitude': '',
#    'availableBikes': 32,
#    'availableDocks': 21,
#    'city': '',
#    'id': 3641,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:58 PM',
#    'latitude': 40.74286877312112,
#    'location': '',
#    'longitude': -73.98918628692627,
#    'postalCode': '',
#    'stAddress1': 'Broadway & W 25 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & W 25 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 54},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 24,
#    'city': '',
#    'id': 3642,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:13 PM',
#    'latitude': 40.78728519860952,
#    'location': '',
#    'longitude': -73.95012259483337,
#    'postalCode': '',
#    'stAddress1': 'E 98 St & Lexington Ave',
#    'stAddress2': '',
#    'stationName': 'E 98 St & Lexington Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 54,
#    'city': '',
#    'id': 3643,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:33 PM',
#    'latitude': 40.75272201381188,
#    'location': '',
#    'longitude': -73.98123621940613,
#    'postalCode': '',
#    'stAddress1': 'E 41 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'E 41 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 24,
#    'availableDocks': 0,
#    'city': '',
#    'id': 3644,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:04 PM',
#    'latitude': 40.67581622522832,
#    'location': '',
#    'longitude': -74.01488184928894,
#    'postalCode': '',
#    'stAddress1': 'Van Dyke St & Van Brunt St',
#    'stAddress2': '',
#    'stationName': 'Van Dyke St & Van Brunt St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 24,
#    'city': '',
#    'id': 3646,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:24 PM',
#    'latitude': 40.76315481910373,
#    'location': '',
#    'longitude': -73.93985509872437,
#    'postalCode': '',
#    'stAddress1': '35 Ave & 10 St',
#    'stAddress2': '',
#    'stationName': '35 Ave & 10 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 26},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 10,
#    'city': '',
#    'id': 3647,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:22 PM',
#    'latitude': 40.74128309355993,
#    'location': '',
#    'longitude': -73.93725872039794,
#    'postalCode': '',
#    'stAddress1': '48 Ave & 30 Pl',
#    'stAddress2': '',
#    'stationName': '48 Ave & 30 Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 16,
#    'city': '',
#    'id': 3648,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:40 PM',
#    'latitude': 40.697950315695444,
#    'location': '',
#    'longitude': -73.97077560424805,
#    'postalCode': '',
#    'stAddress1': 'Flushing Ave & Vanderbilt Ave',
#    'stAddress2': '',
#    'stationName': 'Flushing Ave & Vanderbilt Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 22,
#    'city': '',
#    'id': 3649,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:57 PM',
#    'latitude': 40.814394437915816,
#    'location': '',
#    'longitude': -73.95324736833572,
#    'postalCode': '',
#    'stAddress1': 'W 129 St & Convent Ave',
#    'stAddress2': '',
#    'stationName': 'W 129 St & Convent Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 19,
#    'city': '',
#    'id': 3653,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:38 PM',
#    'latitude': 40.75820464696758,
#    'location': '',
#    'longitude': -73.92832159996033,
#    'postalCode': '',
#    'stAddress1': '31 St & 35 Ave',
#    'stAddress2': '',
#    'stationName': '31 St & 35 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 35,
#    'city': '',
#    'id': 3654,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:13 PM',
#    'latitude': 40.75186951421875,
#    'location': '',
#    'longitude': -73.93349289894103,
#    'postalCode': '',
#    'stAddress1': '31 St & Northern Blvd',
#    'stAddress2': '',
#    'stationName': '31 St & Northern Blvd',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 26,
#    'city': '',
#    'id': 3656,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:25:14 PM',
#    'latitude': 40.72307749068673,
#    'location': '',
#    'longitude': -73.98583620786667,
#    'postalCode': '',
#    'stAddress1': 'E 2 St & Avenue A',
#    'stAddress2': '',
#    'stationName': 'E 2 St & Avenue A',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 22,
#    'city': '',
#    'id': 3658,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:36 PM',
#    'latitude': 40.7435337324616,
#    'location': '',
#    'longitude': -74.00367558002472,
#    'postalCode': '',
#    'stAddress1': 'W 18 St & 9 Ave',
#    'stAddress2': '',
#    'stationName': 'W 18 St & 9 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 20,
#    'city': '',
#    'id': 3659,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:42 PM',
#    'latitude': 40.74294891660091,
#    'location': '',
#    'longitude': -74.00413691997528,
#    'postalCode': '',
#    'stAddress1': 'W 17 St & 9 Ave',
#    'stAddress2': '',
#    'stationName': 'W 17 St & 9 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 38,
#    'city': '',
#    'id': 3660,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:59 PM',
#    'latitude': 40.741021509002664,
#    'location': '',
#    'longitude': -74.001384973526,
#    'postalCode': '',
#    'stAddress1': 'W 16 St & 8 Ave',
#    'stAddress2': '',
#    'stationName': 'W 16 St & 8 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 13,
#    'city': '',
#    'id': 3661,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:23:24 PM',
#    'latitude': 40.666439306870814,
#    'location': '',
#    'longitude': -73.9605563879013,
#    'postalCode': '',
#    'stAddress1': 'Montgomery St & Franklin Ave',
#    'stAddress2': '',
#    'stationName': 'Montgomery St & Franklin Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 18,
#    'city': '',
#    'id': 3662,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:24:48 PM',
#    'latitude': 40.761293897289086,
#    'location': '',
#    'longitude': -73.916916847229,
#    'postalCode': '',
#    'stAddress1': '31 Ave & Steinway St',
#    'stAddress2': '',
#    'stationName': '31 Ave & Steinway St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 21},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 20,
#    'city': '',
#    'id': 3663,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:21:26 PM',
#    'latitude': 40.67716489469059,
#    'location': '',
#    'longitude': -73.973827958107,
#    'postalCode': '',
#    'stAddress1': 'Sterling Pl & 7 Ave',
#    'stAddress2': '',
#    'stationName': 'Sterling Pl & 7 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 29,
#    'city': '',
#    'id': 3664,
#    'landMark': '',
#    'lastCommunicationTime': '2018-02-21 05:22:15 PM',
#    'latitude': 40.72019521437465,
#    'location': '',
#    'longitude': -74.0103006362915,
#    'postalCode': '',
#    'stAddress1': 'North Moore St & Greenwich St',
#    'stAddress2': '',
#    'stationName': 'North Moore St & Greenwich St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 0,
#    'city': '',
#    'id': 3666,
#    'landMark': '',
#    'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#    'latitude': 40.766425527028794,
#    'location': '',
#    'longitude': -73.92062902450562,
#    'postalCode': '',
#    'stAddress1': 'Coming Soon: 32 St & 30 Ave',
#    'stAddress2': '',
#    'stationName': 'Coming Soon: 32 St & 30 Ave',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 0}]}

# %%
# convert the relevant part to a geodataframe
df = gp.GeoDataFrame(data['stationBeanList'])
df.head()
# Out:
#   altitude  availableBikes  availableDocks city   id landMark  \
# 0                        4              35        72
# 1                       25               7        79
# 2                       14              12        82
# 3                       30              30        83
# 4                        7              11       119
#
#     lastCommunicationTime   latitude location  longitude postalCode  \
# 0  2018-02-21 05:20:34 PM  40.767272          -73.993929
# 1  2018-02-21 05:19:55 PM  40.719116          -74.006667
# 2  2018-02-21 05:21:54 PM  40.711174          -74.000165
# 3  2018-02-21 05:20:38 PM  40.683826          -73.976323
# 4  2018-02-21 05:20:18 PM  40.696089          -73.978034
#
#                       stAddress1 stAddress2                    stationName  \
# 0               W 52 St & 11 Ave                          W 52 St & 11 Ave
# 1       Franklin St & W Broadway                  Franklin St & W Broadway
# 2         St James Pl & Pearl St                    St James Pl & Pearl St
# 3  Atlantic Ave & Fort Greene Pl             Atlantic Ave & Fort Greene Pl
# 4       Park Ave & St Edwards St                  Park Ave & St Edwards St
#
#    statusKey statusValue  testStation  totalDocks
# 0          1  In Service        False          39
# 1          1  In Service        False          33
# 2          1  In Service        False          27
# 3          1  In Service        False          62
# 4          1  In Service        False          19

# %%
# there is one row for each bike station.  How many stations are there? 
len(df)
# Out:
# 813

# %%
df.to_crs?

# %%
# in the file above, there are lon-lats, but no geometry field
# we need to set that up

s = gp.GeoSeries([Point(x, y) for x, y in zip(df['longitude'], df['latitude'])])
df['geometry'] = s
df.crs = {'init': 'epsg:4326', 'no_defs': True}
df.geometry.total_bounds
# Out:
# array([-74.0969366 ,  40.65539977, -73.9077436 ,  40.81439444])

# %%
# make sure they are on the same CRS.  
# checking the bounds is a nice way of seeing this
df.to_crs(boros.crs, inplace=True)
df.geometry.total_bounds
# Out:
# array([  957370.14732176,   178056.37414829,  1009803.53178432,
#          235986.42166716])

# %%
# the geometry objects can do lots of cool stuff.  For example: 

manhattan = boros.geometry[3]
in_mn = df.geometry.within(manhattan)
print(sum(in_mn), 'stations in Manhattan')
# Out:
# 414 stations in Manhattan

# %%
df.geometry.within?

# %% [markdown]
# # Your turn
#
# You can read about the range of operations available in geopandas here:
#
# http://geopandas.org/index.html
#
# Your assignment is to:
#
# 1. Calculate how many stations are in each borough
# 2. Calculate how many bikes are currently available in each borough
# 3. Read about and try at least two new spatial or geometric operations (beyond what I've covered here).

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp
from shapely.geometry import Point
import pandas as pd

# %%
boros = gp.read_file('nybb_15b/nybb.shp')
boros
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330466.075042  1.623827e+09
# 1         3       Brooklyn  741185.900596  1.937597e+09
# 2         4         Queens  897040.298576  3.045168e+09
# 3         1      Manhattan  358408.460709  6.364467e+08
# 4         2          Bronx  464400.198868  1.186973e+09
#
#                                             geometry
# 0  (POLYGON ((970217.0223999023 145643.3322143555...
# 1  (POLYGON ((1021176.479003906 151374.7969970703...
# 2  (POLYGON ((1029606.076599121 156073.8142089844...
# 3  (POLYGON ((981219.0557861328 188655.3157958984...
# 4  (POLYGON ((1012821.805786133 229228.2645874023...

# %%
# set the index to be the name of the borough, and sort in order of the borough code
boros.reset_index(inplace=True)
boros.set_index('BoroName', inplace=True)
boros.sort_values(by='BoroCode', inplace=True)
boros
# Out:
#                index  BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Manhattan          3         1  358408.460709  6.364467e+08
# Bronx              4         2  464400.198868  1.186973e+09
# Brooklyn           1         3  741185.900596  1.937597e+09
# Queens             2         4  897040.298576  3.045168e+09
# Staten Island      0         5  330466.075042  1.623827e+09
#
#                                                         geometry
# BoroName
# Manhattan      (POLYGON ((981219.0557861328 188655.3157958984...
# Bronx          (POLYGON ((1012821.805786133 229228.2645874023...
# Brooklyn       (POLYGON ((1021176.479003906 151374.7969970703...
# Queens         (POLYGON ((1029606.076599121 156073.8142089844...
# Staten Island  (POLYGON ((970217.0223999023 145643.3322143555...

# %%
station_mn = df.geometry.within(boros.geometry[0])
station_brnx = df.geometry.within(boros.geometry[1])
station_queens = df.geometry.within(boros.geometry[3])
station_sttn = df.geometry.within(boros.geometry[4])
station_brkln = df.geometry.within(boros.geometry[2])

print(sum(station_sttn),"stations in staten island",sum(station_mn),"in manhattan",sum(station_brnx),"in bronx",sum(station_brkln),"in brooklyn")
# Out:
# 0 stations in staten island 414 in manhattan 0 in bronx 266 in brooklyn

# %%
total=0
#count=0
for row in range(0,len(df)):
    if df['geometry'][row].within(boros.geometry[2])==True:
        total=total+df['availableBikes'][row]
        #count=count+1
print ("total available bikes in brooklyn",total)
# Out:
# total available bikes in brooklyn 1848
