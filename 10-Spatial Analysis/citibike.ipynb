# %% [markdown]
# # Example: CitiBike data
#
# Adapted from Kelsey Jordahl
# https://gist.github.com/kjordahl/5957573

# %%
import requests  
import json
from pyproj import Proj
from shapely.geometry import Point
import geopandas as gp

# %% [markdown]
# NYC borough boundaries downloaded from [Bytes of the Big Apple](http://www.nyc.gov/html/dcp/download/bytes/nybb_13a.zip)

# %%
boros = gp.GeoDataFrame.from_file('nybb_15b/nybb.shp')

# %% [markdown]
# Load real time bike station data from [CitiBike](http://citibikenyc.com) json API:

# %%
# get the bike data and convert it to a ditcionary
endpoint_url = 'http://citibikenyc.com/stations/json'
response = requests.get(endpoint_url)
data = json.loads(response.text)

# %%
# convert the relevant part to a geodataframe
df = gp.GeoDataFrame(data['stationBeanList'])
df.head()
# Out:
#   altitude  availableBikes  availableDocks city   id landMark  \
# 0                        7              32        72
# 1                       30               3        79
# 2                       15              12        82
# 3                       22              38        83
# 4                       14               5       119
#
#     lastCommunicationTime   latitude location  longitude postalCode  \
# 0  2018-02-20 11:27:53 AM  40.767272          -73.993929
# 1  2018-02-20 11:30:46 AM  40.719116          -74.006667
# 2  2018-02-20 11:29:38 AM  40.711174          -74.000165
# 3  2018-02-20 11:30:20 AM  40.683826          -73.976323
# 4  2018-02-20 11:29:06 AM  40.696089          -73.978034
#
#                       stAddress1 stAddress2                    stationName  \
# 0               W 52 St & 11 Ave                          W 52 St & 11 Ave
# 1       Franklin St & W Broadway                  Franklin St & W Broadway
# 2         St James Pl & Pearl St                    St James Pl & Pearl St
# 3  Atlantic Ave & Fort Greene Pl             Atlantic Ave & Fort Greene Pl
# 4       Park Ave & St Edwards St                  Park Ave & St Edwards St
#
#    statusKey statusValue  testStation  totalDocks
# 0          1  In Service        False          39
# 1          1  In Service        False          33
# 2          1  In Service        False          27
# 3          1  In Service        False          62
# 4          1  In Service        False          19

# %%
# there is one row for each bike station.  How many stations are there? 
len(df)
# Out:
# 813

# %%
# in the file above, there are lon-lats, but no geometry field
# we need to set that up

s = gp.GeoSeries([Point(x, y) for x, y in zip(df['longitude'], df['latitude'])])
df['geometry'] = s
df.crs = {'init': 'epsg:4326', 'no_defs': True}
df.geometry.total_bounds
# Out:
# array([-74.0969366 ,  40.65539977, -73.9077436 ,  40.81439444])

# %%
# make sure they are on the same CRS.  
# checking the bounds is a nice way of seeing this
df.to_crs(boros.crs, inplace=True)
df.geometry.total_bounds
# Out:
# array([  957370.14732176,   178056.37414829,  1009803.53178432,
#          235986.42166716])

# %%
# the geometry objects can do lots of cool stuff.  For example: 

manhattan = boros.geometry[3]
in_mn = df.geometry.within(manhattan)
print(sum(in_mn), 'stations in Manhattan')
# Out:
# 414 stations in Manhattan

# %% [markdown]
# # Your turn
#
# You can read about the range of operations available in geopandas here:
#
# http://geopandas.org/index.html
#
# Your assignment is to:
#
# 1. Calculate how many stations are in each borough
# 2. Calculate how many bikes are currently available in each borough
# 3. Read about and try at least two new spatial or geometric operations (beyond what I've covered here).

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp
from shapely.geometry import Point
import pandas as pd

# %%
boros = gp.read_file('nybb_15b/nybb.shp')
boros
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330466.075042  1.623827e+09
# 1         3       Brooklyn  741185.900596  1.937597e+09
# 2         4         Queens  897040.298576  3.045168e+09
# 3         1      Manhattan  358408.460709  6.364467e+08
# 4         2          Bronx  464400.198868  1.186973e+09
#
#                                             geometry
# 0  (POLYGON ((970217.0223999023 145643.3322143555...
# 1  (POLYGON ((1021176.479003906 151374.7969970703...
# 2  (POLYGON ((1029606.076599121 156073.8142089844...
# 3  (POLYGON ((981219.0557861328 188655.3157958984...
# 4  (POLYGON ((1012821.805786133 229228.2645874023...

# %%
# set the index to be the name of the borough, and sort in order of the borough code
boros.reset_index(inplace=True)
boros.set_index('BoroName', inplace=True)
boros.sort_values(by='BoroCode', inplace=True)
boros
# Out:
#                index  BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Manhattan          3         1  358408.460709  6.364467e+08
# Bronx              4         2  464400.198868  1.186973e+09
# Brooklyn           1         3  741185.900596  1.937597e+09
# Queens             2         4  897040.298576  3.045168e+09
# Staten Island      0         5  330466.075042  1.623827e+09
#
#                                                         geometry
# BoroName
# Manhattan      (POLYGON ((981219.0557861328 188655.3157958984...
# Bronx          (POLYGON ((1012821.805786133 229228.2645874023...
# Brooklyn       (POLYGON ((1021176.479003906 151374.7969970703...
# Queens         (POLYGON ((1029606.076599121 156073.8142089844...
# Staten Island  (POLYGON ((970217.0223999023 145643.3322143555...

# %%
station_mn = df.geometry.within(boros.geometry[0])
station_brnx = df.geometry.within(boros.geometry[1])
station_queens = df.geometry.within(boros.geometry[3])
station_sttn = df.geometry.within(boros.geometry[4])
station_brkln = df.geometry.within(boros.geometry[2])

print(sum(station_sttn),"stations in staten island",sum(station_mn),"in manhattan",sum(station_brnx),"in bronx",sum(station_brkln),"in brooklyn")
# Out:
# 0 stations in staten island 414 in manhattan 0 in bronx 266 in brooklyn

# %%
df
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 0                          7              32         72
# 1                         30               3         79
# 2                         15              12         82
# 3                         22              38         83
# 4                         14               5        119
# 5                          0              17        120
# 6                         24               6        127
# 7                         29               0        128
# 8                         14              10        143
# 9                         14               5        144
# 10                        26              13        146
# 11                         0              30        150
# 12                        31               1        151
# 13                        22               7        152
# 14                         9              14        157
# 15                        34               0        161
# 16                        22              24        164
# 17                         6              38        167
# 18                        45               0        168
# 19                        12              38        173
# 20                         1              29        174
# 21                        18              27        195
# 22                        19               7        212
# 23                        10              12        216
# 24                         0               0        217
# 25                         5              28        223
# 26                        24              31        228
# 27                        21               0        229
# 28                         1              21        232
# 29                         0              39        236
# ..       ...             ...             ...  ...   ...      ...
# 783                        1              21       3625
# 784                        0               0       3628
# 785                       22              10       3629
# 786                        0               0       3630
# 787                        4              23       3631
# 788                        0              33       3632
# 789                        2              38       3635
# 790                        1              30       3637
# 791                       14               4       3638
# 792                        3              27       3639
# 793                        3              15       3640
# 794                       51               1       3641
# 795                        2              22       3642
# 796                       11              44       3643
# 797                       17               6       3644
# 798                        2              23       3646
# 799                       12              11       3647
# 800                       10              13       3648
# 801                        4              26       3649
# 802                        0              19       3653
# 803                        0              35       3654
# 804                        0              31       3656
# 805                       24               1       3658
# 806                       22               1       3659
# 807                       10              26       3660
# 808                        7              12       3661
# 809                        0              21       3662
# 810                        4              21       3663
# 811                       28               2       3664
# 812                        0               0       3666
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 0    2018-02-20 11:27:53 AM  40.767272          -73.993929
# 1    2018-02-20 11:30:46 AM  40.719116          -74.006667
# 2    2018-02-20 11:29:38 AM  40.711174          -74.000165
# 3    2018-02-20 11:30:20 AM  40.683826          -73.976323
# 4    2018-02-20 11:29:06 AM  40.696089          -73.978034
# 5    2018-02-20 11:28:02 AM  40.686768          -73.959282
# 6    2018-02-20 11:28:30 AM  40.731724          -74.006744
# 7    2018-02-20 11:30:06 AM  40.727103          -74.002971
# 8    2018-02-20 11:29:52 AM  40.692395          -73.993379
# 9    2018-02-20 11:28:23 AM  40.698399          -73.980689
# 10   2018-02-20 11:30:08 AM  40.716250          -74.009106
# 11   2018-02-20 11:28:40 AM  40.720874          -73.980858
# 12   2018-02-20 11:28:39 AM  40.722104          -73.997249
# 13   2018-02-20 11:31:04 AM  40.714740          -74.009106
# 14   2018-02-20 11:29:12 AM  40.690893          -73.996123
# 15   2018-02-20 11:29:24 AM  40.729170          -73.998102
# 16   2018-02-20 11:30:48 AM  40.753231          -73.970325
# 17   2018-02-20 11:28:02 AM  40.748901          -73.976049
# 18   2018-02-20 11:30:00 AM  40.739713          -73.994564
# 19   2018-02-20 11:31:31 AM  40.760683          -73.984527
# 20   2018-02-20 11:31:16 AM  40.738177          -73.977387
# 21   2018-02-20 11:28:04 AM  40.709056          -74.010434
# 22   2018-02-20 11:31:33 AM  40.743349          -74.006818
# 23   2018-02-20 11:30:55 AM  40.700379          -73.995481
# 24   2018-02-09 08:49:17 AM  40.702772          -73.993836
# 25   2018-02-20 11:29:56 AM  40.737815          -73.999947
# 26   2018-02-20 11:28:49 AM  40.754601          -73.971879
# 27   2018-02-20 11:29:25 AM  40.727434          -73.993790
# 28   2018-02-20 11:29:36 AM  40.695977          -73.990149
# 29   2018-02-20 11:30:36 AM  40.728419          -73.987140
# ..                      ...        ...      ...        ...        ...
# 783  2018-02-20 11:29:11 AM  40.752576          -73.936428
# 784  1969-12-31 07:00:00 PM  40.802557          -73.949078
# 785  2018-02-20 11:30:18 AM  40.809495          -73.947765
# 786  1969-12-31 07:00:00 PM  40.803865          -73.955931
# 787  2018-02-20 11:29:39 AM  40.666563          -73.956741
# 788  2018-02-20 11:27:58 AM  40.728049          -73.978812
# 789  2018-02-20 11:28:55 AM  40.754623          -73.995168
# 790  2018-02-20 11:28:11 AM  40.683239          -73.965996
# 791  2018-02-20 11:29:40 AM  40.724294          -74.035483
# 792  2018-02-20 11:31:28 AM  40.719252          -74.034234
# 793  2018-02-20 11:28:29 AM  40.733670          -74.062500
# 794  2018-02-20 11:30:36 AM  40.742869          -73.989186
# 795  2018-02-20 11:28:51 AM  40.787285          -73.950123
# 796  2018-02-20 11:29:19 AM  40.752722          -73.981236
# 797  2018-02-20 11:30:52 AM  40.675816          -74.014882
# 798  2018-02-20 11:31:32 AM  40.763155          -73.939855
# 799  2018-02-20 11:29:35 AM  40.741283          -73.937259
# 800  2018-02-20 11:30:20 AM  40.697950          -73.970776
# 801  2018-02-20 11:29:30 AM  40.814394          -73.953247
# 802  2018-02-20 11:28:39 AM  40.758205          -73.928322
# 803  2018-02-20 11:29:28 AM  40.751870          -73.933493
# 804  2018-02-20 11:28:30 AM  40.723077          -73.985836
# 805  2018-02-20 11:30:40 AM  40.743534          -74.003676
# 806  2018-02-20 11:28:23 AM  40.742949          -74.004137
# 807  2018-02-20 11:29:13 AM  40.741022          -74.001385
# 808  2018-02-20 11:30:17 AM  40.666439          -73.960556
# 809  2018-02-20 11:29:17 AM  40.761294          -73.916917
# 810  2018-02-20 11:29:39 AM  40.677165          -73.973828
# 811  2018-02-20 11:30:21 AM  40.720195          -74.010301
# 812  1969-12-31 07:00:00 PM  40.766426          -73.920629
#
#                                           stAddress1 stAddress2  \
# 0                                   W 52 St & 11 Ave
# 1                           Franklin St & W Broadway
# 2                             St James Pl & Pearl St
# 3                      Atlantic Ave & Fort Greene Pl
# 4                           Park Ave & St Edwards St
# 5                        Lexington Ave & Classon Ave
# 6                              Barrow St & Hudson St
# 7                           MacDougal St & Prince St
# 8                          Clinton St & Joralemon St
# 9                                Nassau St & Navy St
# 10                              Hudson St & Reade St
# 11                                 E 2 St & Avenue C
# 12                          Cleveland Pl & Spring St
# 13                             Warren St & Church St
# 14                           Henry St & Atlantic Ave
# 15                             LaGuardia Pl & W 3 St
# 16                                   E 47 St & 2 Ave
# 17                                   E 39 St & 3 Ave
# 18                                   W 18 St & 6 Ave
# 19                                Broadway & W 49 St
# 20                                   E 25 St & 1 Ave
# 21                             Liberty St & Broadway
# 22                           W 16 St & The High Line
# 23                   Columbia Heights & Cranberry St
# 24                                     Old Fulton St
# 25                                   W 13 St & 7 Ave
# 26                                   E 48 St & 3 Ave
# 27                                    Great Jones St
# 28                       Cadman Plaza E & Tillary St
# 29                               St Marks Pl & 2 Ave
# ..                                               ...        ...
# 783                                   28 St & 40 Ave
# 784                Coming Soon: Lenox Ave & W 117 St
# 785              Adam Clayton Powell Blvd & W 126 St
# 786  Coming Soon: Frederick Douglass Blvd & W 115 St
# 787                           Crown St & Bedford Ave
# 788                               E 12 St & Avenue B
# 789                                  W 36 St & 9 Ave
# 790                          Fulton St & Waverly Ave
# 791                                    Washington St
# 792                                       Harborside
# 793                                   Journal Square
# 794                               Broadway & W 25 St
# 795                          E 98 St & Lexington Ave
# 796                                  E 41 St & 5 Ave
# 797                       Van Dyke St & Van Brunt St
# 798                                   35 Ave & 10 St
# 799                                   48 Ave & 30 Pl
# 800                    Flushing Ave & Vanderbilt Ave
# 801                           W 129 St & Convent Ave
# 802                                   31 St & 35 Ave
# 803                            31 St & Northern Blvd
# 804                                E 2 St & Avenue A
# 805                                  W 18 St & 9 Ave
# 806                                  W 17 St & 9 Ave
# 807                                  W 16 St & 8 Ave
# 808                     Montgomery St & Franklin Ave
# 809                             31 Ave & Steinway St
# 810                              Sterling Pl & 7 Ave
# 811                    North Moore St & Greenwich St
# 812                      Coming Soon: 32 St & 30 Ave
#
#                                          stationName  statusKey  \
# 0                                   W 52 St & 11 Ave          1
# 1                           Franklin St & W Broadway          1
# 2                             St James Pl & Pearl St          1
# 3                      Atlantic Ave & Fort Greene Pl          1
# 4                           Park Ave & St Edwards St          1
# 5                        Lexington Ave & Classon Ave          1
# 6                              Barrow St & Hudson St          1
# 7                           MacDougal St & Prince St          1
# 8                          Clinton St & Joralemon St          1
# 9                                Nassau St & Navy St          1
# 10                              Hudson St & Reade St          1
# 11                                 E 2 St & Avenue C          1
# 12                          Cleveland Pl & Spring St          1
# 13                             Warren St & Church St          1
# 14                           Henry St & Atlantic Ave          1
# 15                             LaGuardia Pl & W 3 St          1
# 16                                   E 47 St & 2 Ave          1
# 17                                   E 39 St & 3 Ave          1
# 18                                   W 18 St & 6 Ave          1
# 19                                Broadway & W 49 St          1
# 20                                   E 25 St & 1 Ave          1
# 21                             Liberty St & Broadway          1
# 22                           W 16 St & The High Line          1
# 23                   Columbia Heights & Cranberry St          1
# 24                                     Old Fulton St          3
# 25                                   W 13 St & 7 Ave          1
# 26                                   E 48 St & 3 Ave          1
# 27                                    Great Jones St          1
# 28                       Cadman Plaza E & Tillary St          1
# 29                               St Marks Pl & 2 Ave          1
# ..                                               ...        ...
# 783                                   28 St & 40 Ave          1
# 784                Coming Soon: Lenox Ave & W 117 St          3
# 785              Adam Clayton Powell Blvd & W 126 St          1
# 786  Coming Soon: Frederick Douglass Blvd & W 115 St          3
# 787                           Crown St & Bedford Ave          1
# 788                               E 12 St & Avenue B          1
# 789                                  W 36 St & 9 Ave          1
# 790                          Fulton St & Waverly Ave          1
# 791                                    Washington St          1
# 792                                       Harborside          1
# 793                                   Journal Square          1
# 794                               Broadway & W 25 St          1
# 795                          E 98 St & Lexington Ave          1
# 796                                  E 41 St & 5 Ave          1
# 797                       Van Dyke St & Van Brunt St          1
# 798                                   35 Ave & 10 St          1
# 799                                   48 Ave & 30 Pl          1
# 800                    Flushing Ave & Vanderbilt Ave          1
# 801                           W 129 St & Convent Ave          1
# 802                                   31 St & 35 Ave          1
# 803                            31 St & Northern Blvd          1
# 804                                E 2 St & Avenue A          1
# 805                                  W 18 St & 9 Ave          1
# 806                                  W 17 St & 9 Ave          1
# 807                                  W 16 St & 8 Ave          1
# 808                     Montgomery St & Franklin Ave          1
# 809                             31 Ave & Steinway St          1
# 810                              Sterling Pl & 7 Ave          1
# 811                    North Moore St & Greenwich St          1
# 812                      Coming Soon: 32 St & 30 Ave          3
#
#         statusValue  testStation  totalDocks  \
# 0        In Service        False          39
# 1        In Service        False          33
# 2        In Service        False          27
# 3        In Service        False          62
# 4        In Service        False          19
# 5        In Service        False          19
# 6        In Service        False          31
# 7        In Service        False          30
# 8        In Service        False          24
# 9        In Service        False          19
# 10       In Service        False          39
# 11       In Service        False          31
# 12       In Service        False          33
# 13       In Service        False          29
# 14       In Service        False          23
# 15       In Service        False          35
# 16       In Service        False          47
# 17       In Service        False          45
# 18       In Service        False          47
# 19       In Service        False          51
# 20       In Service        False          30
# 21       In Service        False          45
# 22       In Service        False          28
# 23       In Service        False          23
# 24   Not In Service        False           2
# 25       In Service        False          33
# 26       In Service        False          55
# 27       In Service        False          23
# 28       In Service        False          23
# 29       In Service        False          39
# ..              ...          ...         ...
# 783      In Service        False          22
# 784  Not In Service        False           0
# 785      In Service        False          33
# 786  Not In Service        False           0
# 787      In Service        False          27
# 788      In Service        False          33
# 789      In Service        False          41
# 790      In Service        False          31
# 791      In Service        False          18
# 792      In Service        False          30
# 793      In Service        False          18
# 794      In Service        False          54
# 795      In Service        False          24
# 796      In Service        False          55
# 797      In Service        False          24
# 798      In Service        False          26
# 799      In Service        False          23
# 800      In Service        False          25
# 801      In Service        False          30
# 802      In Service        False          19
# 803      In Service        False          35
# 804      In Service        False          31
# 805      In Service        False          27
# 806      In Service        False          25
# 807      In Service        False          39
# 808      In Service        False          19
# 809      In Service        False          21
# 810      In Service        False          25
# 811      In Service        False          30
# 812  Not In Service        False           0
#
#                                         geometry
# 0     POINT (985931.706502895 218814.7571059909)
# 1     POINT (982402.0068864136 201269.770346975)
# 2     POINT (984204.131576321 198376.4207269395)
# 3     POINT (990816.693171227 188413.5778061197)
# 4    POINT (990341.0662772973 192881.3587593974)
# 5     POINT (995542.6499674907 189487.130991468)
# 6    POINT (982380.8081703536 205863.5336667247)
# 7    POINT (983426.5668231644 204179.6463416795)
# 8    POINT (986086.0608250959 191534.6892925949)
# 9     POINT (989604.659795354 193722.6190909547)
# 10    POINT (981725.7239503184 200225.863801748)
# 11   POINT (989556.0615834089 201910.8022852982)
# 12   POINT (985012.5446468905 202358.4293712162)
# 13   POINT (981725.5641854072 199675.6701459276)
# 14     POINT (985325.028738052 190987.311705364)
# 15   POINT (984775.9628196507 204932.9545571026)
# 16   POINT (992471.6913760394 213700.4296134548)
# 17    POINT (990886.3316149795 212122.247093652)
# 18   POINT (985756.3868449081 208774.0542709137)
# 19   POINT (988536.3806696547 216414.5279701727)
# 20   POINT (990516.6660584905 208215.0171926057)
# 21    POINT (981357.2947618697 197604.967062631)
# 22   POINT (982360.8588185154 210098.9152547596)
# 23   POINT (985503.1386279116 194443.3320134889)
# 24   POINT (985959.0741029026 195315.1719141323)
# 25   POINT (984264.7956262807 208082.5352398808)
# 26   POINT (992041.0680657702 214199.4676623823)
# 27    POINT (985971.136067108 204300.5237780721)
# 28    POINT (986981.680449689 192839.7324420954)
# 29   POINT (987814.4333672459 204659.3610184811)
# ..                                           ...
# 783  POINT (1001863.366169073 213466.7249954364)
# 784  POINT (998347.9173225384 231674.1216610379)
# 785  POINT (998709.9933259726 234202.3661690303)
# 786  POINT (996450.5060902653 232149.9347964355)
# 787  POINT (996250.9068352756 182126.2341534543)
# 788  POINT (990122.6922679136 204524.9966832282)
# 789  POINT (985588.8304040538 214206.3194960145)
# 790  POINT (993681.0531251264 188200.5193282779)
# 791  POINT (974414.9408303761 203158.4080368268)
# 792  POINT (974760.3095222107 201321.1689145829)
# 793   POINT (966928.7021517028 206578.527770047)
# 794  POINT (987246.5072421131 209923.9372304686)
# 795   POINT (998061.9402500548 226110.055129331)
# 796  POINT (989448.7220673489 213514.1609436496)
# 797  POINT (980122.0516570791 185494.8346404181)
# 798  POINT (1000911.228370526 217320.3354354134)
# 799  POINT (1001636.179602486 209352.2651814067)
# 800   POINT (992353.6136338996 193559.929864458)
# 801  POINT (997191.3635010964 235986.4216671567)
# 802  POINT (1004107.691792768 215519.2301035001)
# 803  POINT (1002676.794449477 213210.0061366847)
# 804  POINT (988175.9885107474 202713.4851785591)
# 805  POINT (983231.4976422871 210166.0395165557)
# 806  POINT (983103.6503884804 209952.9781649697)
# 807  POINT (983866.2096913268 209250.7382518516)
# 808  POINT (995192.4627268018 182080.6695978765)
# 809   POINT (1007266.181429797 216647.535658214)
# 810   POINT (991509.491009593 185986.9274302788)
# 811  POINT (981394.6962497386 201663.2336897716)
# 812  POINT (1006236.118588554 218516.2031063868)
#
# [813 rows x 19 columns]
